# %%
import re
import os

# %%
## Teste de Leitura
#with open('inscritos-form.json', 'r') as myfile:
   #data = myfile.read()
#print(data)
#myfile.close()


# problema do backslash na cria~ão de ir

# %%
def trataJson(jfile):
    with open(jfile, 'r') as myfile:
        data = myfile.read()
    content = data
    fatl=re.sub(r'\n',' ',data)      
    fatl=re.sub(r'[^i]*inscritos\"\:\[','',fatl)
    fatl=re.sub(r'}    ] }','',fatl)       
    dataA=re.split(r'},{', fatl)
    for i in range(len(dataA)):
        dataA[i]=re.split(r'\"\,\s*\"', dataA[i])
        for j in range(len(dataA[i])):
            cena=re.split(r'\"\:\"', dataA[i][j])
            if(len(cena)>1):
                dataA[i][j]= cena[1]
            else:
                dataA[i][j]= "NaN"     
        dataA[i][6]=re.sub(r'\"','',dataA[i][6])     # problema do ultimo jogador ter " no fim da equipa
        dataA[i][6]=re.sub(r'\/','',dataA[i][6])    # problema do backslash na cria~ão de ir
        dataA[i][6]=re.sub(r'\s+$','',dataA[i][6])
    myfile.close()
    return dataA

# %%
def getdataLine(linha):
    name = re.search(r'([^"]*)',linha[0])
    dataNasc = re.search(r'([^"]*)',linha[1])
    morada = re.search(r'([^"]*)',linha[2])
    email = re.search(r'([^"]*)',linha[3])
    prova = re.search(r'([^"]*)',linha[4])
    escalao = re.search(r'([^"]*)',linha[5])
    equipa = re.search(r'([^"]*)',linha[6])
    
    return name, dataNasc, morada, email,prova,escalao,equipa

# %%
def showMeDist(dataSplited):
    print(0,"- nome -",dataSplited[1][0])
    print(1,"- dataNasc -",dataSplited[1][1])
    print(2,"- morada -",dataSplited[1][2])
    print(3,"- email -",dataSplited[1][3])
    print(4,"- prova -",dataSplited[1][4])
    print(5,"- escalao -",dataSplited[1][5])
    print(6,"- equipa -",dataSplited[1][6])

# %% [markdown]
# # Processador de Inscritos numa atividade Desportiva

# %% [markdown]
# Neste exercício pretende-se trabalhar com um arquivo desportivo criado por um Organizador de Provas de Orientação realizadas em diferentes locais e para diferentes graus de dificuldade adaptadas a diferentes classes de participantes.

# %% [markdown]
# Construa, então, um ou vários programas Python para processar o ficheiro de texto 'inscritos.json' anexo1 conforme solicitado nas alíneas seguintes:
#
#
#     a) imprimir o nome (convertido para maiúsculas) de todos os concorrentes que se inscrevem como 'Individuais' e são de 'Valongo'.
#     b) imprimir o nome completo, o telemóvel e a prova em que está inscrito cada concorrente cujo nome seja 'Paulo' ou 'Ricardo', desde que seja da Vodafone.
#     c) imprimir toda a informação dos atletas da equipe "TURBULENTOS".
#     d) imprimir a lista dos escalões por ordem alfabética e para cada um indicar quantos atletas estão inscritos nesse escalão.
#     e) gerar uma página HTML com a lista das equipes inscritas em qualquer prova, indicando o seu nome e o número dos atletas que a constituem e que se inscreveram pelo menos uma vez numa prova; essa lista deve estar ordenada por ordem decrescente do número de atletas; além disso, cada equipe deve ter um link para outra página HTML com a informação que achar interessante sobre cada atleta indicando as provas em que cada um participou.

# %% [markdown]
# a) imprimir o nome (convertido para maiúsculas) de todos os concorrentes que se inscrevem como 'Individuais' e são de 'Valongo'.

# %%
dataSplited=trataJson('inscritos-form.json')
showMeDist(dataSplited)
# Out:
# 0 - nome - Francisco Neto Silva
# 1 - dataNasc - 22/04/89
# 2 - morada - Rua da Ermida, 235
# 3 - email - netosilva.francisco@gmail.com
# 4 - prova - Corrida da Geira
# 5 - escalao - SENIOR Masc
# 6 - equipa - individual

# %%
for linha in dataSplited:
    morada =re.search(r'(?i:Valongo)',linha[2])
    if(morada):
        individual = re.search(r'(?i:Individual)',linha[6])
    
        if(individual): 
            name, dataNasc, moradaS, email,prova,escalao,equipa= getdataLine(linha)
            print('Nome de Inscrito: ',name[1].upper(),'\n' )
            f = open('PLTP01_exA.txt', "a")
            f.write('''Resposta:
            ''')
            f.write('''Nome de Inscrito: 
            ''')
            f.write(name[1].upper())
            f.write('\n')
            f.close()
# Out:
# Nome de Inscrito:  VERA CRISTINA MOREIRA DELGADO
#
# Nome de Inscrito:  PAULO DOMINGUES
#
# Nome de Inscrito:  DULCE MOREDA

# %% [markdown]
# b) imprimir o nome completo, o telemóvel e a prova em que está inscrito cada concorrente cujo nome
# seja 'Paulo' ou 'Ricardo', desde que usem o GMail.

# %%
dataSplited=trataJson('inscritos-form.json')
showMeDist(dataSplited)
# Out:
# 0 - nome - Francisco Neto Silva
# 1 - dataNasc - 22/04/89
# 2 - morada - Rua da Ermida, 235
# 3 - email - netosilva.francisco@gmail.com
# 4 - prova - Corrida da Geira
# 5 - escalao - SENIOR Masc
# 6 - equipa - individual

# %%
for linha in dataSplited:
    paulo =re.search(r'(?i:Paulo)',linha[0]) 
    ricardo =re.search(r'(?i:Ricardo)',linha[0])
    if((paulo or ricardo)):
        gmail = re.search(r'(?i:@gmail)',linha[3])
    
        if( gmail): 
            f = open('PLTP01_exB.txt', "a")
            name, dataNasc, morada, email,prova,escalao,equipa= getdataLine(linha)
            resp='Dados de Utilizador:'+'\n'+ 'Nome: '+name[1].upper()+'\n'+'Email: '+email[1]+'\n'+'Prova: '+prova[1]+'\n'+'\n'
            print(resp)
            f.write(resp)
            f.close()
# Out:
# Dados de Utilizador:
# Nome: PAULO DE CASTRO ROCHA
# Email: pcastrorocha@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: J PAULO MARQUES
# Email: pmarques269@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: PAULO SERRA
# Email: paulo.serra@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: PAULO VILAÇA
# Email: pmv777@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: PAULO DOMINGUES
# Email: p.j.p.domingues@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: RICARDO JORGE DIAS OLIVEIRA
# Email: Ricardo.transportesabranco@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: RICARDO REIS
# Email: ricardoreiis@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: PAULO FÉLIX
# Email: pauloalexteixeirafelix@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: JOÃO RICARDO TAVARES NEVES
# Email: rwichers4@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: RICARDO SOUSA
# Email: jose.ricardo.sousa@gmail.com
# Prova: Corrida da Geira
#
#
# Dados de Utilizador:
# Nome: RICARDO JORGE DIAS OLIVEIRA
# Email: helderfva@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: RICARDO COUTO
# Email: rjcouto@gmail.com
# Prova: Ultra Trail
#
#
# Dados de Utilizador:
# Nome: RICARDO ERNESTO DOS SANTOS GERALDES DOMINGUES
# Email: santosgeraldes@gmail.com
# Prova: Corrida da Geira

# %% [markdown]
#  c) imprimir toda a informação dos atletas da equipe "TURBULENTOS".

# %%
dataSplited=trataJson('inscritos-form.json')
showMeDist(dataSplited)
# Out:
# 0 - nome - Francisco Neto Silva
# 1 - dataNasc - 22/04/89
# 2 - morada - Rua da Ermida, 235
# 3 - email - netosilva.francisco@gmail.com
# 4 - prova - Corrida da Geira
# 5 - escalao - SENIOR Masc
# 6 - equipa - individual

# %%
for linha in dataSplited:
    
    turb = re.search(r'^(?i:TURBULENTOS$)',linha[6]) ## turbulentos vs os turbolentos <- ver isto
    if(turb ): 
        f = open('PLTP01_exC.txt', "a")
        name, dataNasc, morada, email,prova,escalao,equipa= getdataLine(linha)
        resp='Dados de Utilizador:'+'\n'+ 'Nome: '+name[1].upper()+'\n'+'Data de Nascimento: '+dataNasc[1]+'\n'+'Morada: '+morada[1]+'\n'+'Email: '+email[1]+'\n'+'Prova: '+prova[1]+'\n'+'Escalão: '+escalao[1]+'\n'+'Prova: '+equipa[1]+'\n'+'\n'
        print(resp)
        f.write(resp)
        f.close()
# Out:
# Dados de Utilizador:
# Nome: JOÃO COSTA
# Data de Nascimento: 04/04/70
# Morada: Rua Carolina Rosa Alves Nº27 Braga
# Email: jfscosta@gmail.com
# Prova: Ultra Trail
# Escalão: M40
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: PAULO PIMENTEL TORRES
# Data de Nascimento: 10/09/59
# Morada: Rua Costa Soares, 39
# Email: geral@vieirafreitas.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: JOÃO PIMENTEL TORRES
# Data de Nascimento: 11/09/88
# Morada: Rua Costa Soares, 39
# Email: geral@vieirafreitas.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: VASCO MANUEL DE SEQUEIROS BARRETO MARTINS DE ARAÚJO
# Data de Nascimento: 26/05/64
# Morada: Rua S. Domingos 174 3º esq.
# Email: vascosequeiros@yahoo.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: CELESTE CRUZ
# Data de Nascimento: 23/10/65
# Morada: Rua Graça Júnior, nº 14, Braga
# Email: mcrus@stec.uminho.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: JORGE LOURENÇO
# Data de Nascimento: 27/10/69
# Morada: Rua Eduardo Esperança, 7
# Email: jlourenzo@hotmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: LUÍS MELO
# Data de Nascimento: 11/09/67
# Morada: R. Feliciano Ramos, Nº 24 - 11º Esq. Frt.
# Email: lume_pereira@yahoo.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: MARIO JORGE AORIMM
# Data de Nascimento: 11/12/66
# Morada: R.Eng.Pimentel 19 4715-359 Braga
# Email: mjgsmamorim@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: LUIS B PEREIRA
# Data de Nascimento: 05/08/61
# Morada: Rua Damião de Gois, 198-5ª Esq 4700-028-Braga
# Email: luis.pereira@grupoecb.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: PAULO ANTUNES
# Data de Nascimento: 16/09/73
# Morada: Rua Eduardo Manuel de Almeida nº 648 5º Direito
# Email: psantunes@sapo.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: CARLOS ALBERTO GOMES TEIXEIRA
# Data de Nascimento: 08/06/69
# Morada: R. António F. F. Gomes, 138, 4º Esq. 4705-157 Braga
# Email: carlosflaviae@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: MANEL ALBERTO LEITE DE SOUSA
# Data de Nascimento: 15/05/66
# Morada: Rua Germão Galharde, 16   5DTFT
# Email: mna.sousa@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: GIUSEPPE BALDASSARRE
# Data de Nascimento: 30/04/66
# Morada: Av.Joao XXI 730
# Email: badgi.p@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: HELENA OLIVEIRA
# Data de Nascimento: 11/12/86
# Morada: Av.Joao XXI 730
# Email: helena-mendes.oliveira@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: PAULO ANTUNES
# Data de Nascimento: 16/09/73
# Morada: Rua Eduardo Manuel de Almeida nº 648 5º Direito
# Email: psantunes@sapo.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: MARINHA PAULA FERNANDES
# Data de Nascimento: 19/12/65
# Morada: Rua do Outeiro, nº 28 Lamaçães Braga
# Email: paula.fer@netcabo.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: CÁTIA RAQUEL MACEDO OLIVEIRA
# Data de Nascimento: 14/08/83
# Morada: Rua Serrões nº899 4760-247 Vila Nova de Famalicão
# Email: catia_oliveira83@hotmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: MANUEL COUTINHO MACHADO
# Data de Nascimento: 04/03/67
# Morada: Urbanização do Rio - Rua 1 - nº 31 - 4º esqº 4905-313 Ponte
# Email: couto67@gmail.com
# Prova: Ultra Trail
# Escalão: M40
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: TIAGO DOMINGUES FRADA
# Data de Nascimento: 10/01/82
# Morada: Rua Germão Galharde, nº 26, 3º tro Trás, 4715-290 Braga
# Email: tiagofrada@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: ANTÓNIO JOSÉ COSTA
# Data de Nascimento: 04/05/60
# Morada: rua costa soares - braga
# Email: tozecosta1960@hotmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: Turbulentos
#
#
# Dados de Utilizador:
# Nome: TIAGO DOMINGUES FRADA
# Data de Nascimento: 10/01/82
# Morada: Rua Germão galharde, nº 26, 3º Ctro Trás, Braga
# Email: tiagofrada@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: MARIO JORGE AORIMM
# Data de Nascimento: 11/12/66
# Morada: R. Eng Pimentel 19 Braga
# Email: mjgsmamorim@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: JOSÉ FERREIRA LOUREIRO
# Data de Nascimento: 25/04/65
# Morada: Rua Rodrigo Gonçalves Costa nº13 - 4715-230 -Braga
# Email: jfloureiros@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: CARLOS MANUEL GONÇALVES VIEIRA FERNANDES
# Data de Nascimento: 14/03/66
# Morada: Rua do Outeiro, nº 28 LAmaçães - 4715-082 Braga
# Email: carlos.fer@netcabo.pt
# Prova: Ultra Trail
# Escalão: M40
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: JOSE ALBERTO MARTINS
# Data de Nascimento: 06/09/63
# Morada: Rua Costa Soares 14
# Email: geral@bragalis.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: SANDRA MARIA FINSTERRA TRAVESSAS
# Data de Nascimento: 16/04/14
# Morada: Rua gomes d Amorim 2350 Aveiro mar P varzim
# Email: Sandra.travessas@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: FRANCISCO ANTÓNIO DOS SANTOS COSTAS
# Data de Nascimento: 08/06/64
# Morada: Praça Dr Francisco Araújo Malheiro nº 76 3º Dt
# Email: xicocosta@yahoo.com
# Prova: Ultra Trail
# Escalão: M40
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: CARLOS BRITO
# Data de Nascimento: 16/01/70
# Morada: Rua da Mourisca 51 4710 - 087 Braga
# Email: carlosmcbrito@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: Turbulentos
#
#
# Dados de Utilizador:
# Nome: ELISABETE COSTA
# Data de Nascimento: 21/05/79
# Morada: rua santa cruz vimieiro braga
# Email: elisabetecosta78@hotmail.com
# Prova: Ultra Trail
# Escalão: SENIOR Fem
# Prova: turbulentos
#
#
# Dados de Utilizador:
# Nome: ANTÓNIO FERREIRA
# Data de Nascimento: 10/02/61
# Morada: Rua Albanao Belino, 42 - 3º esq. 4710-351 Braga
# Email: anjomafe@sas.uminho.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: ANTÓNIO JOSÉ VELOSO DOS SANTOS
# Data de Nascimento: 05/04/63
# Morada: Rua do Outeiro, 52, Lamaçães, 4715-082 Braga
# Email: a.veloso.santos@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: ANA MOREIRA
# Data de Nascimento: 21/07/61
# Morada: R. Conego Constantino Souto Mayor Nº7,  7ºD.  4715 287 Braga
# Email: ruisantosmail@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: JOÃO NUNO FERREIRA CRUZ PINTO
# Data de Nascimento: 30/07/72
# Morada: Av. Dr. Porfirio da Silva 290 - 6º
# Email: joao.nuno@portugalmail.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: MÁRIO RAMOS
# Data de Nascimento: 25/08/64
# Morada: Dr João Araujo Nº226 , 4910 433 Vila Praia Ancora
# Email: ruisantosmail@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: CONCEIÇÃO MARQUES
# Data de Nascimento: 17/03/63
# Morada: Avª Antero de Quental, nº 60, 6º Esqº Trás - Braga
# Email: cmarques@dps.uminho.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: SÉRGIO SILVA
# Data de Nascimento: 26/12/59
# Morada: Avª Alfredo Barros, nº 4, 5º Dtº - Braga
# Email: sergio_pirata@sapo.pt
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: PAULA MATOS
# Data de Nascimento: 16/01/65
# Morada: R. Prof. Machado Vilela 180 2º trás - Braga
# Email: paulamatoso@yayoo.com.br
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: SHEILA PEREIRA KHAN
# Data de Nascimento: 02/10/72
# Morada: Rua do Assento, Quinta da Seara, Hab.D, Gondizalves
# Email: sheilakhan31@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Fem
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: RUI GOMES
# Data de Nascimento: 27/12/72
# Morada: Rua Amândio César nº5, 1ºDF
# Email: rui.rodrigues.gomes@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS
#
#
# Dados de Utilizador:
# Nome: JOSÉ MARIA RIBEIRO VIEIRA DE FIGUEIREDO
# Data de Nascimento: 05/02/69
# Morada: Braga
# Email: osvaldo.s.oliveira@gmail.com
# Prova: Corrida da Geira
# Escalão: SENIOR Masc
# Prova: TURBULENTOS

# %% [markdown]
# d) imprimir a lista dos escalões por ordem alfabética e para cada um indicar quantos atletas estão inscritos nesse escalão.

# %%
dataSplited=trataJson('inscritos-form.json')
showMeDist(dataSplited)
# Out:
# 0 - nome - Francisco Neto Silva
# 1 - dataNasc - 22/04/89
# 2 - morada - Rua da Ermida, 235
# 3 - email - netosilva.francisco@gmail.com
# 4 - prova - Corrida da Geira
# 5 - escalao - SENIOR Masc
# 6 - equipa - individual

# %%
d = dict()
for linha in dataSplited:
    if linha[5] not in d:
        d[linha[5]] = 1
    else:
        d[linha[5]]+=1

for x in sorted(d):
    f = open('PLTP01_exD.txt', "a")
    escalao = x
    n=d[x]
    resp='---Dados de escalão---'+'\n'+ 'Nome de escalão: '+'\''+escalao+'\''+'\n'+'Numero de Inscritos: '+str(n)+'\n'+'\n'
    print(resp)
    f.write(resp)
    f.close()
# Out:
# ---Dados de escalão---
# Nome de escalão: ''
# Numero de Inscritos: 12
#
#
# ---Dados de escalão---
# Nome de escalão: 'F40'
# Numero de Inscritos: 3
#
#
# ---Dados de escalão---
# Nome de escalão: 'M40'
# Numero de Inscritos: 36
#
#
# ---Dados de escalão---
# Nome de escalão: 'M50'
# Numero de Inscritos: 12
#
#
# ---Dados de escalão---
# Nome de escalão: 'SENIOR Fem'
# Numero de Inscritos: 43
#
#
# ---Dados de escalão---
# Nome de escalão: 'SENIOR Masc'
# Numero de Inscritos: 175

# %%
#primeiro ciclo vai buscar todos os escalões e ordena 
# 2º ciclo vai a lista e pega nos nomes dos do dado escalão
# - escalão : 
# tendo a estrutura imprime

# %% [markdown]
# e) gerar uma página HTML com a lista das equipes inscritas em qualquer prova, indicando o seu nome e o número dos atletas que a constituem e que se inscreveram pelo menos uma vez numa prova;
#
# essa lista deve estar ordenada por ordem decrescente do número de atletas;
#
# além disso, cada equipe deve ter um link para outra página HTML com a informação que achar interessante sobre cada atleta indicando as provas em que cada um participou.

# %% [markdown]
# <html>
#     <head>
#         <h1>Pagina de apresentação de equipas<h1>
#     </head>
#     <body>
#         <equipa> <h2>Team 1</h2>
#             <jogador>
#                 <nome> player 1</nome>
#                 <cena> cena 1</cena>
#             </jogador>
#         </equipa>
#     </body>
# </html>

# %%
# 1 º equipas + numero de atletas
# ordenar lista por ordem decrescente de n de atletas
# Link para outra pagina html
    # ATLETAS DE 1 EQUIPA (nome) com informação de provas em que está inscrito

# %%
dataSplited=trataJson('inscritos-form.json')
showMeDist(dataSplited)
# Out:
# 0 - nome - Francisco Neto Silva
# 1 - dataNasc - 22/04/89
# 2 - morada - Rua da Ermida, 235
# 3 - email - netosilva.francisco@gmail.com
# 4 - prova - Corrida da Geira
# 5 - escalao - SENIOR Masc
# 6 - equipa - individual

# %%
lteam=[]
lnome=[]
# lteam - nomes equipas
# lnome - [
            #[
                #(nome,informações)
            #]
        #]
        #[[equipa1],[equipa2]]
for linha in dataSplited:
    name, dataNasc, morada, email,prova,escalao,equipa= getdataLine(linha)
    if equipa[1].upper() not in lteam:
        
        lteam.append(equipa[1].upper())
        lnome.append([(name[1],[dataNasc[1], morada[1], email[1],prova[1],escalao[1],equipa[1]])])
    else:
        lnome[lteam.index(equipa[1].upper())].append((name[1],[dataNasc[1], morada[1], email[1],prova[1],escalao[1],equipa[1]]))
#print(lteam)
#print(lnome)

# %%
lfinal=[]
for i in range(len(lteam)):
    lfinal.append((lteam[i], lnome[i], len(lnome[i])))
lfinal = sorted(lfinal, key=lambda tup: tup[2],reverse=True)

lfinal
# Out:
# [('INDIVIDUAL',
#   [('MARIO PIRES',
#     ['04/04/59',
#      'RUA CÂNDIDO DOS REIS , nº 86 , 2º ,',
#      'mgpires@netcabo.pt',
#      'Ultra Trail',
#      'M50',
#      'Individual']),
#    ('Francisco Neto Silva',
#     ['22/04/89',
#      'Rua da Ermida, 235',
#      'netosilva.francisco@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'individual']),
#    ('Artur Bernardo',
#     ['22/05/72',
#      'Rua Jose Relvas n8',
#      'ajbernardo@netcabo.pt',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Vera Cristina Moreira Delgado',
#     ['28/11/80',
#      'rua do freixo, 51 - Valongo',
#      'veramdelgado@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('Jorge Yong',
#     ['13/11/70',
#      'Barcelos',
#      'pintojo@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Paulo Serra',
#     ['22/08/81',
#      'Maia',
#      'paulo.serra@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Tiago José Cadima Borges',
#     ['15/10/82',
#      'Rua do Campos Verdes nº161 R/C',
#      'tjcborges@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('jorge manuel martins silva',
#     ['17/06/68',
#      'rua domingos nunes lt 2',
#      'jorge.silva2005@sapo.pt',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Paulo Domingues',
#     ['05/08/70',
#      'Valongo',
#      'p.j.p.domingues@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Dulce Moreda',
#     ['25/05/69',
#      'Valongo',
#      'dulcemoreda@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('António Fernandes',
#     ['24/05/77',
#      'Rua S. Tiago Nº297, Caldelas',
#      'cisterbtt@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Vera Cristina Moreira Delgado',
#     ['28/11/80',
#      'rua do freixo, 51',
#      'veramdelgado@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('Angelo Senra',
#     ['21/12/75',
#      'Rua da Quinta Seca 313 4º andar',
#      'angelosenra@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Paulo Jorge',
#     ['02/12/67',
#      'Av. Dr. Carlos Bacelar',
#      'pjloureiro@live.com.pt',
#      'Ultra Trail',
#      'F40',
#      'Individual']),
#    ('António Fernandes',
#     ['24/05/77',
#      'Rua S. Tiago Nº297, Caldelas',
#      'cisterbtt@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Vitor Marques',
#     ['08/07/85',
#      'RUA DA TAIPA',
#      'vitruh@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Sérgio Martins',
#     ['09/07/80',
#      'praceta bispo d. pedro nº 4 1º dt 4715-171 Braga',
#      'sergiomartinsfut@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Nuno Lima',
#     ['12/07/72',
#      'Av. Republica,1758,4410-496 Arcozelo',
#      'nunopintolima@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Paula Cristina Oliveira',
#     ['01/02/71',
#      'Rio Tinto',
#      'paulacoliveira@portugalmail.pt',
#      'Ultra Trail',
#      'F40',
#      'Individual']),
#    ('Nuno coelho silva',
#     ['06/08/75',
#      'rua Antero de Quental 809 3ª, 4200 Porto',
#      'nchibelo@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Artur Ferreira',
#     ['01/10/70',
#      'Rua Porfirio Gomes Moreira, Lote 32 - 4740 Esposende',
#      'artur.ferreira@samson.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Vasco Ortigão de Oliveira',
#     ['09/02/70',
#      'Rua Campos Monteiro, 81 - Porto',
#      'vortigao@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Ricardo Jorge Dias Oliveira',
#     ['25/11/81',
#      'Rua da Portela nº77 4825-197 Guimarei  Santo Tirso',
#      'Ricardo.transportesabranco@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Nuno Carvalhal',
#     ['12/12/74',
#      'Av. D. Afonso Henriques, 1105, 6ºesq.',
#      'tinocarvalhal@hotmail.com',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Andre Sousa',
#     ['09/06/78',
#      'Porto',
#      'andrehsh@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Susana Dias',
#     ['31/08/84',
#      'Matosinhos',
#      'andrehsh@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('Marco Tiago Marques Rodrigues',
#     ['21/07/78',
#      'Rua do Outeiro,nº 186 4620-196 Nogueira',
#      'orthosapiens@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Marco Tiago Marques Rodrigues',
#     ['21/07/78',
#      'Rua do Outeiro,nº186 4620-196 Nogueira',
#      'orthosapiens@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('elisabete costa',
#     ['21/05/78',
#      'rua santa cruz nº20 vimieiro braga',
#      'elisabetecosta78@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'Individual']),
#    ('Antonio Lafuente Coelho de Azevedo',
#     ['25/09/51',
#      'Rua Dr João Afonso Almeida, 580-6º-E',
#      'ant.lafuente@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Rui André Santos Oliveira',
#     ['21/04/75',
#      'Rua João Conde, 2 4740-305 Esposende',
#      'rui.a.oliveira@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Carlos Freitas',
#     ['29/04/77',
#      'Rua Ofélia Cruz Costa, 560 - 2o Esq 4455-137 Lavra',
#      'crodrigues.freitas@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Miguel Borges',
#     ['20/05/77',
#      'Braga',
#      'borges.miguel@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('sergio ferreira rodrigues',
#     ['06/03/58',
#      'viseu',
#      'sergio.ferreira.rodrigues@cgd.pt',
#      'Ultra Trail',
#      'M50',
#      'individual']),
#    ('Jorge Costa',
#     ['01/12/81',
#      'V.N.Famalicão',
#      'jorgef.rcosta@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('carla sofia lima leite nunes garcez',
#     ['25/06/74',
#      'marzovelos viseu',
#      'carla.garcez@cgd.pt',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'Individual']),
#    ('Alberto César',
#     ['24/12/70',
#      'Fânzeres',
#      'almanoce@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('José Mendes',
#     ['02/11/66',
#      'Gualtar, Braga',
#      'jotamendes2@hotmail.com',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Joaquim Alves',
#     ['13/01/74',
#      'Gualtar, Braga',
#      'jbs.alves@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Vitor Pedro Silva',
#     ['01/10/76',
#      'Av. do Monte, 6324770-324 Landim, V.N.Famalicão',
#      'vpsilva76@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Susana Neta',
#     ['27/03/76',
#      'Rua Monsenhor Miguel Sampaio, 185, RC AP4',
#      'netasusana@gmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'Individual']),
#    ('Alberto César',
#     ['24/12/70',
#      'Fânzeres',
#      'almanoce@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Vitor Marques',
#     ['08/07/85',
#      'rua da Taipa, nº241 3ºC',
#      'vitruh@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Jose Pereira',
#     ['10/08/79',
#      'Av. Visconde Barreiros nº195 Ap. 8.1',
#      'josetpereira@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Rodrigo Miguel',
#     ['05/10/77',
#      'Rua Rui Gameiro nº91 4460-800 Custóias',
#      'rodmpoliveira@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('João Ricardo Tavares Neves',
#     ['02/11/67',
#      'Urb. Gorgolão II Edifício Solaris 2º Esq. 3020-199',
#      'rwichers4@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Individual']),
#    ('Carlos Figueiredo',
#     ['26/06/76',
#      'Rua Monte de Baixo 98',
#      'longras.figueiredo@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Alberto Barros',
#     ['06/07/69',
#      'CC Gondomar 1 4705-472 Cunha BRG',
#      'alberto.barros@portugalmail.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'individual']),
#    ('Amândio Antunes',
#     ['14/03/77',
#      'Vila Praia de Âncora',
#      'amandiofantunes@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Patrícia Amorim',
#     ['13/02/84',
#      'Vila Praia de Âncora',
#      'patriciaamorim@portugalmail.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('António Fernando Fins',
#     ['18/03/61',
#      'Tr. Nova Entroncamento nº 2 4720-424 Figue. Amares',
#      'afefins@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Rui Manuel Alves Monteiro Araujo',
#     ['07/08/86',
#      'Rua das Tapadas n.99',
#      'ruimanuaraujo@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Pedro Castro',
#     ['16/07/79',
#      'Faldejães Arcozelo',
#      'p.pereiracastro@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Rui Pedro Ribeiro Ferreira',
#     ['09/09/72',
#      'Rua Anibal Ferreira Basto Ed. Milénio BL A FR L',
#      'ruperife@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Ligia Susana Miguel Dias',
#     ['23/06/74',
#      'Rua Anibal Ferreira Basto Ed. Milénio BL A FR L',
#      'ligiaadias@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('Joana Azevedo',
#     ['02/12/82',
#      'Marco de Canaveses',
#      'joana.ip.azevedo@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Individual']),
#    ('Rui Santos',
#     ['03/05/64',
#      'R. Conego Constantino Souto Mayor Nº7,  7ºD.  4715 287 Braga',
#      'ruisantosmail@gmail.com',
#      'Ultra Trail',
#      'M50',
#      'individual']),
#    ('carlos manuel mendes pereira',
#     ['28/12/81',
#      'rua da cernada nº6 vila ruiva 3520-224',
#      'cmendespereira@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Luis Melo',
#     ['08/03/77',
#      'Chaves',
#      'luiscarlos.flavibetao@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Olga Melo',
#     ['',
#      'Chaves',
#      'olga_saoresmelo@hotmail.com',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'Individual']),
#    ('Ricardo Ernesto dos Santos Geraldes Domingues',
#     ['17/04/78',
#      'Av. Altino Coelho nº 136, R/c 02, 4470-233 Maia',
#      'santosgeraldes@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Individual']),
#    ('Alexandre Solposto',
#     ['04/02/78',
#      'Estrada Municipal 510, Qtª Alegria, Penalva. Barreiro',
#      'ledoalex@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual']),
#    ('Rui Pinto',
#     ['19/09/74',
#      'R. Padre Amaro - 304C - 1º Dto - 4455-109 Lavra MTS',
#      'ruipinto74mts@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Individual'])],
#   63),
#  ('TURBULENTOS',
#   [('João Costa',
#     ['04/04/70',
#      'Rua Carolina Rosa Alves Nº27 Braga',
#      'jfscosta@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'TURBULENTOS']),
#    ('Paulo Pimentel Torres',
#     ['10/09/59',
#      'Rua Costa Soares, 39',
#      'geral@vieirafreitas.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('João Pimentel Torres',
#     ['11/09/88',
#      'Rua Costa Soares, 39',
#      'geral@vieirafreitas.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Vasco Manuel de Sequeiros Barreto Martins de Araújo',
#     ['26/05/64',
#      'Rua S. Domingos 174 3º esq.',
#      'vascosequeiros@yahoo.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Celeste Cruz',
#     ['23/10/65',
#      'Rua Graça Júnior, nº 14, Braga',
#      'mcrus@stec.uminho.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Jorge Lourenço',
#     ['27/10/69',
#      'Rua Eduardo Esperança, 7',
#      'jlourenzo@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Luís Melo',
#     ['11/09/67',
#      'R. Feliciano Ramos, Nº 24 - 11º Esq. Frt.',
#      'lume_pereira@yahoo.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Mario Jorge Aorimm',
#     ['11/12/66',
#      'R.Eng.Pimentel 19 4715-359 Braga',
#      'mjgsmamorim@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Luis B Pereira',
#     ['05/08/61',
#      'Rua Damião de Gois, 198-5ª Esq 4700-028-Braga',
#      'luis.pereira@grupoecb.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Paulo Antunes',
#     ['16/09/73',
#      'Rua Eduardo Manuel de Almeida nº 648 5º Direito',
#      'psantunes@sapo.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Carlos Alberto Gomes Teixeira',
#     ['08/06/69',
#      'R. António F. F. Gomes, 138, 4º Esq. 4705-157 Braga',
#      'carlosflaviae@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Manel Alberto Leite de Sousa',
#     ['15/05/66',
#      'Rua Germão Galharde, 16   5DTFT',
#      'mna.sousa@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Giuseppe Baldassarre',
#     ['30/04/66',
#      'Av.Joao XXI 730',
#      'badgi.p@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Helena Oliveira',
#     ['11/12/86',
#      'Av.Joao XXI 730',
#      'helena-mendes.oliveira@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Paulo Antunes',
#     ['16/09/73',
#      'Rua Eduardo Manuel de Almeida nº 648 5º Direito',
#      'psantunes@sapo.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Marinha Paula Fernandes',
#     ['19/12/65',
#      'Rua do Outeiro, nº 28 Lamaçães Braga',
#      'paula.fer@netcabo.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Cátia Raquel Macedo Oliveira',
#     ['14/08/83',
#      'Rua Serrões nº899 4760-247 Vila Nova de Famalicão',
#      'catia_oliveira83@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Manuel Coutinho Machado',
#     ['04/03/67',
#      'Urbanização do Rio - Rua 1 - nº 31 - 4º esqº 4905-313 Ponte',
#      'couto67@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'TURBULENTOS']),
#    ('Tiago Domingues Frada',
#     ['10/01/82',
#      'Rua Germão Galharde, nº 26, 3º tro Trás, 4715-290 Braga',
#      'tiagofrada@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('António José Costa',
#     ['04/05/60',
#      'rua costa soares - braga',
#      'tozecosta1960@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Turbulentos']),
#    ('Tiago Domingues Frada',
#     ['10/01/82',
#      'Rua Germão galharde, nº 26, 3º Ctro Trás, Braga',
#      'tiagofrada@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Mario Jorge Aorimm',
#     ['11/12/66',
#      'R. Eng Pimentel 19 Braga',
#      'mjgsmamorim@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('José Ferreira Loureiro',
#     ['25/04/65',
#      'Rua Rodrigo Gonçalves Costa nº13 - 4715-230 -Braga',
#      'jfloureiros@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Carlos Manuel Gonçalves Vieira Fernandes',
#     ['14/03/66',
#      'Rua do Outeiro, nº 28 LAmaçães - 4715-082 Braga',
#      'carlos.fer@netcabo.pt',
#      'Ultra Trail',
#      'M40',
#      'TURBULENTOS']),
#    ('Jose Alberto Martins',
#     ['06/09/63',
#      'Rua Costa Soares 14',
#      'geral@bragalis.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Sandra Maria Finsterra Travessas',
#     ['16/04/14',
#      'Rua gomes d Amorim 2350 Aveiro mar P varzim',
#      'Sandra.travessas@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Francisco António dos Santos Costas',
#     ['08/06/64',
#      'Praça Dr Francisco Araújo Malheiro nº 76 3º Dt',
#      'xicocosta@yahoo.com',
#      'Ultra Trail',
#      'M40',
#      'TURBULENTOS']),
#    ('Carlos Brito',
#     ['16/01/70',
#      'Rua da Mourisca 51 4710 - 087 Braga',
#      'carlosmcbrito@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Turbulentos']),
#    ('elisabete costa',
#     ['21/05/79',
#      'rua santa cruz vimieiro braga',
#      'elisabetecosta78@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'turbulentos']),
#    ('António Ferreira',
#     ['10/02/61',
#      'Rua Albanao Belino, 42 - 3º esq. 4710-351 Braga',
#      'anjomafe@sas.uminho.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('António José Veloso dos Santos',
#     ['05/04/63',
#      'Rua do Outeiro, 52, Lamaçães, 4715-082 Braga',
#      'a.veloso.santos@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('ANA MOREIRA',
#     ['21/07/61',
#      'R. Conego Constantino Souto Mayor Nº7,  7ºD.  4715 287 Braga',
#      'ruisantosmail@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('João Nuno Ferreira Cruz Pinto',
#     ['30/07/72',
#      'Av. Dr. Porfirio da Silva 290 - 6º',
#      'joao.nuno@portugalmail.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('MÁRIO RAMOS',
#     ['25/08/64',
#      'Dr João Araujo Nº226 , 4910 433 Vila Praia Ancora',
#      'ruisantosmail@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Conceição Marques',
#     ['17/03/63',
#      'Avª Antero de Quental, nº 60, 6º Esqº Trás - Braga',
#      'cmarques@dps.uminho.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Sérgio Silva',
#     ['26/12/59',
#      'Avª Alfredo Barros, nº 4, 5º Dtº - Braga',
#      'sergio_pirata@sapo.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('Paula Matos',
#     ['16/01/65',
#      'R. Prof. Machado Vilela 180 2º trás - Braga',
#      'paulamatoso@yayoo.com.br',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Sheila Pereira Khan',
#     ['02/10/72',
#      'Rua do Assento, Quinta da Seara, Hab.D, Gondizalves',
#      'sheilakhan31@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TURBULENTOS']),
#    ('Rui Gomes',
#     ['27/12/72',
#      'Rua Amândio César nº5, 1ºDF',
#      'rui.rodrigues.gomes@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS']),
#    ('José Maria Ribeiro Vieira de Figueiredo',
#     ['05/02/69',
#      'Braga',
#      'osvaldo.s.oliveira@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TURBULENTOS'])],
#   40),
#  ('NAST',
#   [('FERNANDO JORGE MENDES CARNEIRO',
#     ['17/09/82',
#      'Estrada Nacional 105 - n.º 571 - Carreira - Santo Tirso',
#      'nando_1982_sts@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Nast']),
#    ('Gonçalo Mota',
#     ['17/02/73',
#      'Rua Prof. Dr. António Faria Carneiro Pacheco, 180, 12.º B',
#      'gmotamud@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'NAST']),
#    ('Julio Antonio Cunha Peixoto Braga',
#     ['05/08/70',
#      'Rua do Olival n124 2 esq. /4780 512 Santo Tirso',
#      'juliobraga@iol.pt',
#      'Ultra Trail',
#      'M40',
#      'Nast']),
#    ('Helder Fernando Vieira Azevedo',
#     ['03/08/77',
#      'Rua Marques Araujo nº 130 2º esq',
#      'helderfva@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'NAST']),
#    ('Sérgio Paulo dos Santos Sá',
#     ['03/01/77',
#      'rua dos cinco caminhos, 405',
#      'design@sergiosa.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'NAST']),
#    ('Analberto Barros dos Santos',
#     ['12/10/70',
#      'Rua Dr Eduardo Lima carneiro n . 1528',
#      'helderfva@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'NAST']),
#    ('Ricardo Jorge Dias Oliveira',
#     ['11/01/83',
#      'Rua da Portela nº77',
#      'helderfva@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'NAST']),
#    ('Carlos Manuel Oliveira Bras',
#     ['03/01/80',
#      'Rua do Barreiro 87 2º dto',
#      'helderfva@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'NAST']),
#    ('Ana Carolina Lopes Ferreira',
#     ['09/03/74',
#      'Rua Marques Araujo nº 130 2ºesq',
#      'helderfv@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'NAST']),
#    ('Sónia Dolores Ferreira Alves',
#     ['05/04/79',
#      'R. Dr. Carneiro Pacheco, 292 - Blc. A - 1ºDt.',
#      'soniadalves@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'NAST']),
#    ('Deborah Alexandra Lopes Moreira',
#     ['09/02/72',
#      'Rua Dr Eduardo Lima carneiro n . 1528',
#      'deborahlopesmoreira@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'NAST']),
#    ('Julio Antonio Cunha Peixoto Braga',
#     ['05/08/70',
#      'Rua do Olival nº 124 2 esq.',
#      'juliobraga@iol.pt',
#      'Ultra Trail',
#      'M40',
#      'nast'])],
#   12),
#  ('EDV VIANA TRAIL',
#   [('Gabriel Fagundes Meira',
#     ['02/04/74',
#      'Caminho da Mata 172',
#      'gfmeira@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'EDV VIANA TRAIL']),
#    ('José Domingos Fernandes dos Santos',
#     ['23/09/66',
#      'Meadela Viana do CAstelo',
#      'gfmeira@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'EDV VIANA TRAIL']),
#    ('Maria do Rosário Santos',
#     ['',
#      'rua Caminho da Mata nº 172 Viana do Castelo',
#      'gfmeira@gmail.com',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'EDV VIANA TRAIL']),
#    ('Natalina Santos',
#     ['',
#      'rua Caminho da Mata nº 172 Viana do Castelo',
#      'gfmeira@gmail.com',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'EDV VIANA TRAIL']),
#    ('André Saleiro',
#     ['02/01/74',
#      'Viana Do Castelo',
#      'andresaleiro@hotmail.com',
#      'Ultra Trail',
#      'M40',
#      'EDV VIANA TRAIL']),
#    ('Rui Couto',
#     ['28/06/74',
#      'Miramar',
#      'rmcouto@iol.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'EDV VIANA TRAIL']),
#    ('Rosa Lobato',
#     ['26/11/72',
#      'Viana do Castelo',
#      'santossilva.rosa@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'EDV VIANA TRAIL']),
#    ('Anabela Lobato',
#     ['23/02/76',
#      'Viana do Castelo',
#      'jose.alcobia@cargobull.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'EDV VIANA TRAIL']),
#    ('Alexandro Ribeiro',
#     ['28/07/79',
#      'Praça Dr Antonio Feio Ribeiro Silva, n3, 3 dto',
#      'alexandro_ribeiro@msn.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'EDV VIANA TRAIL']),
#    ('Arlindo Alves Rodrigues',
#     ['02/09/70',
#      'rua Carvalheira, 38 - 4900-403 Viana do Castelo',
#      'arlindoalvesrodrigues@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'EDV VIANA TRAIL'])],
#   10),
#  ('ARRASTASSOLAS',
#   [('Pedro Carvalho',
#     ['19/10/72',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'pedrocarvalho@eurospiro.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'ARRASTASSOLAS']),
#    ('Pedro Magalhaes',
#     ['16/03/76',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'maga1976@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'ARRASTASSOLAS']),
#    ('Pedro Lopes',
#     ['16/02/86',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'pedrocarvalho@eurospiro.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'ARRASTASSOLAS']),
#    ('Mario Santos',
#     ['28/03/81',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'pedrocarvalho@eurospiro.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'ARRASTASSOLAS']),
#    ('Vitor Silva',
#     ['1088-08-24',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'pedrocarvalho@eurospiro.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'ARRASTASSOLAS']),
#    ('Helena Cunha',
#     ['22/05/75',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'helena1942@live.com.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'ARRASTASSOLAS']),
#    ('Carla Moreira',
#     ['15/11/74',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'pedrocarvalho@eurospiro.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'ARRASTASSOLAS']),
#    ('Manuel SILVA',
#     ['27/03/69',
#      'Rua da Corredoura nº 25 2º Esq.',
#      'pedrocarvalho@eurospiro.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'ARRASTASSOLAS'])],
#   8),
#  ('MULTIPOWER | GAIA TRAIL',
#   [('João Pedro Pedrosa Nunes',
#     ['11/04/77',
#      'Rua Comendador Joaquim Santos Guimarâes, nº111, 1ºC',
#      'joaorussoci@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL']),
#    ('João Pedro Pedrosa Nunes',
#     ['11/04/77',
#      'Rua Comendador Joaquim Santos Guimarâes, nº111, 1ºC',
#      'joaorussoci@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL']),
#    ('João Pedro Pedrosa Nunes',
#     ['11/04/77',
#      'Rua Comendador Joaquim Santos Guimarâes, nº111, 1ºC',
#      'joaorussoci@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL']),
#    ('João Pedro Pedrosa Nunes',
#     ['11/04/77',
#      'Rua Comendador Joaquim Santos Guimarâes, nº111, 1ºC',
#      'joaorussoci@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL']),
#    ('José Henrique Pinto de Oliveira',
#     ['01/06/85',
#      'Rua da Igreja, nº 1400, 4745-321 Muro',
#      'josehenrique84@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL']),
#    ('Francisco José Carneiro Oliveira',
#     ['06/03/75',
#      'Rua Coats e Clark, nº238, 1º esq, 4430-059 Mafamude',
#      'oliveiraf834@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL']),
#    ('André Peixoto Costa Assunção',
#     ['11/06/77',
#      'Rua Chaquedas, nº256, 4405-717 Vila Nova Gaia',
#      'andre@cm-gaia.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'MULTIPOWER | GAIA TRAIL'])],
#   7),
#  ('PRINT TEAM',
#   [('Carlos Figueiredo',
#     ['06/02/78',
#      'Rua Monte de Baixo n98 Carvalhal',
#      'longras.figueiredo@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Print Team']),
#    ('Abilio Araujo',
#     ['09/10/79',
#      'Rua Padre Albino Vila Seca',
#      'abilioaraujoscp@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Print Team']),
#    ('Vera Costa',
#     ['09/07/84',
#      'Rua Dna Maria II n423 Fradelos V. N. Famalicão',
#      'vcosta4@gmail.com',
#      'Caminhada na Geira - parte II: Museu-Travassos',
#      '',
#      'Print Team']),
#    ('Eugenia Souto',
#     ['12/04/68',
#      'Rua da Igreja nº5 Apulia',
#      'esouto@impetus.pt',
#      'Caminhada na Geira - parte II: Museu-Travassos',
#      '',
#      'Print Team']),
#    ('Susana Figueiredo',
#     ['07/01/76',
#      'Rua Monte de baixo n 98 Carvalhal',
#      'tendenciasgoios@gmail.com',
#      'Caminhada na Geira - parte II: Museu-Travassos',
#      '',
#      'Print Team']),
#    ('Claudia Angeira',
#     ['10/07/84',
#      'Rua da Agra nº61 4740-031 Apulia',
#      'claudia_angeira@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Print Team']),
#    ('Pedro Avelino Silva',
#     ['09/04/84',
#      'Rua dos Navegadores Mindelo',
#      'pedroavelino@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Print Team'])],
#   7),
#  ('PORTO RUNNERS',
#   [('Luis Santos Poeira',
#     ['01/05/66',
#      'R. Soc. Nacional Fósforos, 160 - 1º Andar Hab. 6  4150 Porto',
#      'lspoeira@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Porto Runners']),
#    ('José Fernanades Ferreira',
#     ['09/09/65',
#      'Rua Avelino Soares Carneiro, 111 - R/C - Esº',
#      'j.manuelff@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Porto Runners']),
#    ('Jorge Miguel Marques',
#     ['02/12/69',
#      'Rua do Taralhão, 836 Fanzeres',
#      'mmarques@energest.pt',
#      'Ultra Trail',
#      'M40',
#      'Porto Runners']),
#    ('luis francisco matos marvao',
#     ['07/05/70',
#      'rua professor abel salazar 18 2esq',
#      'luismatosmarvao@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Porto Runners']),
#    ('Nuno Cáceres',
#     ['31/08/68',
#      'rua eugénio de castro, 352, 2, sala 25',
#      'nuno.caceres@mail.telepac.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Porto Runners']),
#    ('Pedro Viana',
#     ['20/12/68',
#      'Rua de Tanger n1307 bloco 4 ,2dto Porto',
#      'Pedrocoutoviana@netcabo.Pt',
#      'Ultra Trail',
#      'M40',
#      'Porto Runners'])],
#   6),
#  ('CLUBE DE VETERANOS DO PORTO',
#   [('paulo de castro rocha',
#     ['22/05/59',
#      'rua gil eanes, 67 - 1º - 4400-165 - vila nova de gaia',
#      'pcastrorocha@gmail.com',
#      'Ultra Trail',
#      'M50',
#      'clube de veteranos do porto']),
#    ('Nuno Manuel Caldeira de Sá',
#     ['07/07/73',
#      'Rua nova de Vilar,93 4475-487 Maia',
#      'nunocsa@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'clube de veteranos do porto']),
#    ('Manuel Pereira',
#     ['25/04/43',
#      'rua fernão magalhães, 511 - 1º esq - rio tint- gondomaro',
#      'geral.pontocom@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'clube de veteranos do Porto']),
#    ('antónio costa',
#     ['23/04/51',
#      'rua gil eanes, 67 - 1º - 4400-165 - vila nova de gaia',
#      'pcastrorocha@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'clube de veteranos do porto']),
#    ('manuel pereira',
#     ['25/04/43',
#      'rua gil eanes, 67 - 1º - 4400-165 - vila nova de gaia',
#      'pcastrorocha@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'clube de veteranos do porto']),
#    ('Nuno Manuel Caldeira de Sá',
#     ['07/07/73',
#      'Rua nova de vilar, 93 4475-487 Maia',
#      'nunocsa@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'clube de veteranos do porto'])],
#   6),
#  ('COMPANHIA DO BAZÓFIAS',
#   [('Artur José Pinto Mendes da Costa',
#     ['07/06/77',
#      'Rua da Constiuição 2365 1º Porto',
#      'artur.jcosta@tesco.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Companhia do Bazófias']),
#    ('Vera Manuela Cardoso da Silva',
#     ['01/08/80',
#      'Rua da Constituição 2365 1º Porto',
#      'artur.jcosta@tesco.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Companhia do Bazófias']),
#    ('Filipe Manuel Pedro Baptista Jesus Nascimento',
#     ['06/07/77',
#      'Rua da Constituição 2365 1º',
#      'artur.jcosta@tesco.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Companhia do Bazófias']),
#    ('João Pedro Martins',
#     ['01/06/77',
#      'Rua da Constituição 2365 1º',
#      'artur.jcosta@tesco.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Companhia do Bazófias']),
#    ('Fernando António Rothes',
#     ['05/04/70',
#      'Rua da Constituição 2365 1º Porto',
#      'artur.jcosta@tesco.pt',
#      'Ultra Trail',
#      'M40',
#      'Companhia do Bazófias']),
#    ('Pedro Miguel Azevedo de Sousa Melo',
#     ['03/09/73',
#      'Rua da Constituição 2365 1º Porto',
#      'artur.jcosta@tesco.pt',
#      'Ultra Trail',
#      'M40',
#      'Companhia do Bazófias'])],
#   6),
#  ('CLUBE NÁUTICO DE PONTE DE LIMA',
#   [('Rafael Brito Abreu Pereira',
#     ['09/08/87',
#      'Ponte de Lima',
#      'rafaelbapereira@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Náutico de Ponte de Lima']),
#    ('Andreia Cunha',
#     ['15/07/92',
#      'ponte de lima',
#      'andreiaccunha@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Clube Náutico de Ponte de Lima']),
#    ('jorge amorim',
#     ['01/02/92',
#      'arribão-facha',
#      'jorge.amorim92@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Náutico de Ponte de Lima']),
#    ('Sara da Costa Sá Correia',
#     ['03/02/80',
#      'Rua José do Rego Lopes',
#      'hhccorreia@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Clube Náutico de Ponte de Lima']),
#    ('Sara da Costa Sá Correia',
#     ['03/02/80',
#      'Rua José do Rego Lopes',
#      'hhccorreia@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Clube Náutico de Ponte de Lima']),
#    ('Renato Martins',
#     ['30/10/79',
#      'Vila Nova de Cerveira',
#      'renato.vnc@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Náutico de Ponte de Lima'])],
#   6),
#  ('CLUBE ATLETISMO DE LAMAS',
#   [('Carlos Alberto da Silva Cardoso',
#     ['08/02/73',
#      'Rua 25 Abril Nr.193',
#      'casc1972@hotmail.com',
#      'Ultra Trail',
#      'M40',
#      'Clube Atletismo de Lamas']),
#    ('Rui Gilberto Santos Correia',
#     ['23/02/74',
#      'Rua Jorge Barradas nr6',
#      'gilcorreia@yahoo.com',
#      'Ultra Trail',
#      'M40',
#      'Clube Atletismo de Lamas']),
#    ('José Moreira',
#     ['12/04/78',
#      'Rua Central nº 905, 1º direito, Fiães',
#      'jmoreiracdf@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Clube Atletismo de Lamas']),
#    ('Hélder Silva',
#     ['09/01/75',
#      'Rua Luis de Camões, 320 2ºDto Post',
#      'helder.santos.silva@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Atletismo de Lamas']),
#    ('JOSE COELHO',
#     ['09/12/78',
#      'RUA PADRE SA N.º 60, 4505-384 FIÃES',
#      'rota_pontual@sapo.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Clube Atletismo de Lamas'])],
#   5),
#  ('TUGAS NA ESTRADA',
#   [('Maria de Fatima Batista Geraldes',
#     ['29/07/69',
#      'Rua Duque da Terceira, nº 249, 1.1, 4050-536 Porto',
#      'mfatima_geraldes@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'Tugas na Estrada']),
#    ('paulo Vilaça',
#     ['09/12/63',
#      'Tv Elaine Sanceau, 51 3ºDto  4465-620 Leça do Balio',
#      'pmv777@gmail.com',
#      'Ultra Trail',
#      'M50',
#      'Tugas na Estrada']),
#    ('Ricardo Silva',
#     ['12/02/14',
#      'Rua das cavadas 178 10 Dtº tras',
#      'jo_ricardo_silva@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Tugas na Estrada']),
#    ('Ricardo Silva',
#     ['12/10/74',
#      'Rua das Cavadas 178 10 Dtº Tras',
#      'jo_ricardo_silva@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Tugas na Estrada']),
#    ('Ricardo Silva',
#     ['12/10/74',
#      'RUA DAS CAVADAS 178 10 DT TRAS',
#      'JRSILVA@pt.cciberianpartners.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Tugas na Estrada'])],
#   5),
#  ('NAN',
#   [('Constância Joana Dias Martins',
#     ['',
#      'Rua Dr Francisco Sa Carneiro nº23 1 Andar 4780 448 S tirso',
#      'joana.faria@mail.telepac.pt',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'NaN']),
#    ('Joaquim Miguel Abreu Faria de Carvalho',
#     ['',
#      'Rua Dr Francisco Sa Carneiro nº23 1 Andar 4780 448 S tirso',
#      'joana.faria@mail.telepac.pt',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'NaN']),
#    ('João Martins Faria',
#     ['',
#      'Rua Dr Francisco Sa Carneiro nº23 1 Andar 4780 448 S tirso',
#      'joana.faria@mail.telepac.pt',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'NaN']),
#    ('Ana Paula Dias Queiros Gomes',
#     ['',
#      'Rua Dr Francisco Sa Carneiro nº23 1 Andar 4780 448 S tirso',
#      'joana.faria@mail.telepac.pt',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'NaN']),
#    ('Ana Isabel Dias Granjo',
#     ['',
#      'Rua Dr Francisco Sa Carneiro nº23 1 Andar 4780 448 S tirso',
#      'joana.faria@mail.telepac.pt',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'NaN'])],
#   5),
#  ('INDIVUDUAL',
#   [('JOSE CARLINDO DUARTE CARVALHO',
#     ['01/06/76',
#      'Rua da Tapada, 14 4700-482 Braga',
#      'jose.carlindo.carvalho@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'INDIVUDUAL']),
#    ('Nuno Lima',
#     ['12/07/72',
#      'Av. Republica, n1758, 4410-496 Arcozelo VNG',
#      'nunopintolima@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'INDIVUDUAL']),
#    ('Silvia Quintiães',
#     ['',
#      'Rua São Mamede, 4990-755 Seara - Ponte de Lima',
#      'silviaquintiaes@gmail.com',
#      'Caminhada em Caldelas - 18 maio',
#      '',
#      'INDIVUDUAL']),
#    ('SIMÃO GRADISSIMO',
#     ['08/02/71',
#      'Oliveira do Douro - Vila Nova de Gaia',
#      'simaogradissimo@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'INDIVUDUAL'])],
#   4),
#  ('CLUBE SPIRIDON DE GAIA',
#   [('Marlene Fonseca',
#     ['07/10/76',
#      'Rua Garcia Resende, 238 3. Esq. Frt. 4430-163 VNGaia',
#      'smfonseca7@gmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'Clube Spiridon de Gaia']),
#    ('Cândido Silva',
#     ['04/11/72',
#      'Rua Pedro Álvares Cabral, 213 4415 Pedroso VNG',
#      'candido72@sapo.pt',
#      'Ultra Trail',
#      'M40',
#      'Clube Spiridon de Gaia']),
#    ('Célia Dias',
#     ['09/07/73',
#      'Rua Pedro Álvares Cabral, 213 4415 Pedroso VNG',
#      'cdias@chvng.min-saude.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Clube Spiridon de Gaia']),
#    ('Daniel Caeiro',
#     ['03/09/79',
#      'Rua Mariano Carvalho, 260 2º DP - 4410-483 Arcozelo - VNGaia',
#      'danicaeiro@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Spiridon de Gaia'])],
#   4),
#  ('OS BARRIGUITAS',
#   [('jose moura de sousa',
#     ['24/01/54',
#      'rua joaquim da silva torres, 261  4470-312 maia',
#      'jomogoso@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'os barriguitas']),
#    ('Manuel Moura',
#     ['27/04/55',
#      'Tv Julio Dinis 124',
#      'mamgs@sapo.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Os Barriguitas']),
#    ('Ricardo Sousa',
#     ['31/10/81',
#      'Rua são Romão 639, apa 301 Maia 4470-365',
#      'jose.ricardo.sousa@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'os barriguitas'])],
#   3),
#  ('EDV-VIANA TRAIL',
#   [('Sonia Parente',
#     ['28/10/77',
#      'Av,Mateus Carvalhido nº19, Sta Maria Maior',
#      'parente.sonia@gmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'EDV-Viana Trail']),
#    ('Célia Azevedo',
#     ['30/07/75',
#      'Rua caminho da mata n 172',
#      'Celiameira@live.com.pt',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'EDV-Viana Trail']),
#    ('José Manuel Santos Faria',
#     ['21/05/86',
#      'Rua do Monte da Tomadia Nº 105 4755-389 Pedra Furada',
#      'znel86@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'EDV-Viana Trail'])],
#   3),
#  ('BRACARA RUNNERS',
#   [('Mauro Fernandes',
#     ['20/04/80',
#      'Rua Fábrica do Pelo, Nº43 3ºC 4710-409 Braga',
#      'colemauro@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Bracara Runners']),
#    ('Rui Filipe',
#     ['13/09/83',
#      'braga',
#      'rui_barbosa83@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Bracara Runners']),
#    ('Rui Filipe',
#     ['14/09/83',
#      'braga',
#      'rui_barbosa83@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Bracara Runners'])],
#   3),
#  ('SOPRO RUN LIFE',
#   [('Renato Lopes',
#     ['10/08/79',
#      'Barcelos',
#      'renato.2.lopes@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'SOPRO RUN LIFE']),
#    ('Moisés Ferreira',
#     ['21/02/75',
#      'Av. D. Nuno Alvares Pereira, 277 3º Dirt. 4750-324 Barcelos',
#      'f_moises@msn.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'SOPRO RUN LIFE']),
#    ('paulo félix',
#     ['15/12/77',
#      'Rua S. Bento nº 33, 3º, esc, 33',
#      'pauloalexteixeirafelix@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'SOPRO RUN LIFE'])],
#   3),
#  ('ECOBIKE PORTO',
#   [('Leandro Costa',
#     ['21/07/83',
#      'Rua Bernardino Costa, nº 458 hab 1.3 Bl D',
#      'costalf1@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Ecobike Porto']),
#    ('Leandro Costa',
#     ['21/07/83',
#      'Rua Bernardino Costa, nº 458 hab 1.3 Bl D',
#      'costalf1@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Ecobike Porto']),
#    ('Leandro Costa',
#     ['21/07/83',
#      'Rua Bernardino Costa, nº 458 hab 1.3 Bl D',
#      'costalf1@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Ecobike Porto'])],
#   3),
#  ('OS CAGA TACOS RUNNING TEAN',
#   [('Bruno Manuel Henriques Maceda',
#     ['11/06/79',
#      'Rua Joaquim Lagoeiro, 11 Veiros Estarreja',
#      'macedobruno10@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Os Caga Tacos Running Tean']),
#    ('Helder Matos',
#     ['07/12/76',
#      'Pcta Nova do picao 114b, 1esq, 4400-424 Canidelo',
#      'Helder_Matos@sapo.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Os Caga Tacos Running Tean'])],
#   2),
#  ('S CLUBE',
#   [('bruno filipe de sa campelo',
#     ['08/03/83',
#      'travessa da escola velha - tregosa - barcelos',
#      'bfcampelo@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      's clube']),
#    ('bruno filipe de sa campelo',
#     ['08/03/83',
#      'travessa da escola velha - tregosa - barcelos',
#      'bfcampelo@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      's clube'])],
#   2),
#  ('.COM',
#   [('Sérgio Duarte',
#     ['06/10/94',
#      'Bairro da Alegria, Rua 10 de Junho nº 11, 4710-332 Braga',
#      'sergioduarte5140@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      '.COM']),
#    ('Celeste Cruz',
#     ['23/10/65',
#      'Rua Graça Júnior, nº 14, Braga',
#      'mcruz@stec.uminho.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      '.COM'])],
#   2),
#  ('UNIÃO FCI DE TOMAR',
#   [('Pedro Albino',
#     ['05/03/78',
#      'Tomar',
#      'albino.pms@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'União FCI de Tomar']),
#    ('Pedro Albino',
#     ['03/05/78',
#      'Tomar',
#      'albino.pms@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'União FCI de Tomar'])],
#   2),
#  ('OS TURBULENTOS',
#   [('Fernando Manuel Tavares da Costa Antunes',
#     ['06/12/56',
#      'Rua S. José, 94 - 2ºDtº - 4710 Braga',
#      'fernandoantunes@ics.uminho.pt',
#      'Ultra Trail',
#      'M50',
#      'Os Turbulentos']),
#    ('Fernando Manuel Tavares da Costa Antunes',
#     ['06/12/56',
#      'Rua S. José, 94 - 2ºDtº - 4710 Braga',
#      'fernandoantunes@ics.uminho.pt',
#      'Ultra Trail',
#      'M50',
#      'Os Turbulentos'])],
#   2),
#  ('TEMPLARTRAIL',
#   [('Jaime Filipe Barros',
#     ['17/07/70',
#      'Leça da Palmeira',
#      'jfb.templarking@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'TemplarTrail']),
#    ('Maria José Valente',
#     ['11/05/68',
#      'Leça da Palmeira',
#      'mjvalente.formar@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'TemplarTrail'])],
#   2),
#  ('CAVE',
#   [('manuel braga',
#     ['30/07/62',
#      'beco das beçadas nº 34 vila cha esposende',
#      'mfpbraga@hotmail.com',
#      'Ultra Trail',
#      'M50',
#      'CAVE']),
#    ('manuel braga',
#     ['30/07/62',
#      'beco das beçadas nº 34 vila cha esposende',
#      'mfpbraga@hotmail.com',
#      'Ultra Trail',
#      'M50',
#      'CAVE'])],
#   2),
#  ('URBAN TEAM',
#   [('Ricardo Campos',
#     ['18/06/79',
#      'Trv. José Camarinha Barrote, nº 63, 2º Esq, 4410-401 VN Gaia',
#      'ric_campos@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Urban Team']),
#    ('Rui Campos',
#     ['06/07/73',
#      'Trv. José Camarinha Barrote, nº 63, 2º Esq, 4410-401 VN Gaia',
#      'ruimcampos@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Urban Team'])],
#   2),
#  ('JC&NIKI',
#   [('José Cunha',
#     ['08/04/78',
#      'Rua de Cidres, 393, 4455-811 Matosinhos',
#      'cunha.josecarlos@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'JC&NIKI']),
#    ('Monica Esteves',
#     ['04/01/80',
#      'Av de Casaldelo nº 2337, 5º dto',
#      'uabmsofia@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'JC&NIKI'])],
#   2),
#  ('PRTAD QUINTA',
#   [('Hugo Sa',
#     ['07/07/84',
#      'Rua do Calvário, 123 - Paramos',
#      'hugo.silva.sa@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'PRTAD QUINTA']),
#    ('Ricardo Reis',
#     ['29/01/81',
#      'Rua vale do vouga, 179',
#      'ricardoreiis@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'PRTAD Quinta'])],
#   2),
#  ('CLUBE NÁUTICO PONTE DE LIMA',
#   [('Luis Gonçalves',
#     ['11/03/77',
#      'Rua São Mamede, 4990-755 Seara- Ponte de Lima',
#      'lamgbtt@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Náutico Ponte de Lima']),
#    ('Nuno Miguel Morais Freitas',
#     ['10/08/78',
#      'Arcozelo - Ponte de Lima',
#      'nuno.corvo@sapo.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Náutico Ponte de Lima'])],
#   2),
#  ('OS TURBOLENTOS',
#   [('Nuno Amorim Silva',
#     ['03/01/75',
#      'Aver-o-Mar',
#      'nuno.f.silva@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Os Turbolentos']),
#    ('Luis Rego da Silva',
#     ['19/02/73',
#      'Aver-o-Mar',
#      'luis.regodasilva@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Os Turbolentos'])],
#   2),
#  ('MINHO AVENTURA',
#   [('Pedro Nóvoa',
#     ['10/02/63',
#      'Rua dos talhos 22 - Tadim',
#      'pedrofilipe.novoa@gmail.com',
#      'Ultra Trail',
#      'M50',
#      'Minho Aventura']),
#    ('Pedro Nóvoa',
#     ['10/02/63',
#      'Rua dos talhos nº22 Tadim',
#      'pedrofilipe.novoa@gmail.com',
#      'Ultra Trail',
#      'M50',
#      'Minho Aventura'])],
#   2),
#  ('CABRITOS DA CORTIÇA - TRAIL',
#   [('Raul Cerdeira',
#     ['25/12/73',
#      'R. José António Cruz 169 2ºET',
#      'raulcerdeira@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'cabritos da cortiça - Trail']),
#    ('Ricardo Couto',
#     ['18/09/14',
#      'Av.  da Carvalha,821 1.1 4510-518',
#      'rjcouto@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'cabritos da cortiça - Trail'])],
#   2),
#  ('PEDROS & ASSOCIADOS',
#   [('Ricardo da Silva Pedro',
#     ['25/02/82',
#      'Lisboa',
#      'Ricardo@soferragens.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Pedros & Associados']),
#    ('Ana Catarina Reis Peixoto',
#     ['14/07/77',
#      'Castelo Branco',
#      'ricardo@soferragens.pt',
#      'Corrida da Geira',
#      'SENIOR Fem',
#      'Pedros & Associados'])],
#   2),
#  ('CLUBE PORTUGAL TELECOM ZONA NORTE',
#   [('Pedro José Gonçalves Braga',
#     ['14/05/83',
#      'Rua Engº Ferreira Dias, nº 380, 4100-246 Porto',
#      'zn@clubept.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Clube Portugal Telecom Zona Norte']),
#    ('Rui Vitor Figueiras Meireles',
#     ['26/07/79',
#      'Rua Engº Ferreira Dias, nº 380, 4100-246 Porto',
#      'zn@clubept.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Clube Portugal Telecom Zona Norte'])],
#   2),
#  ('BANDO DOS TRILHOS E TRALHOS, ASSOCIAÇÃO BETETISTA',
#   [('Bruno Alexandre Oliveira Graça',
#     ['25/10/75',
#      'Trav. João Pinto Ribeiro, n.º 82 - 4435-042 Rio Tinto',
#      'brunonicovr@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Bando dos Trilhos e Tralhos, Associação Betetista']),
#    ('Rui Manuel Almeida Gaspar',
#     ['24/11/72',
#      'Rua Mestra Emília, 96 - 4520-454 Rio Meão',
#      'rumaalga@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Bando dos Trilhos e Tralhos, Associação Betetista'])],
#   2),
#  ('CÃES DA AVENIDA',
#   [('Ricardo Salgueiro',
#     ['22/11/63',
#      'Rua de Gondarém nr 765-5 A 4150-378 Porto',
#      'rs@selcofootwear.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Cães da Avenida'])],
#   1),
#  ('OS CAGA TACOS RUNNING TEAM',
#   [('J Paulo Marques',
#     ['09/06/74',
#      'Tv da Seara N64 3esq 269-4450 Matosinhos',
#      'pmarques269@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Os Caga Tacos Running Team'])],
#   1),
#  ('BLUE O',
#   [('Sérgio Moreira',
#     ['09/09/79',
#      'Rua Nova da Serra, n.º 61 4415-280 Pedroso',
#      'sergio_moreira_79@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Blue O'])],
#   1),
#  ('BORN BE WILD',
#   [('Emanuel Durães',
#     ['05/12/72',
#      'Av.Bombeiros Voluntarios, Nº27 3ºB - 4580-053 Paredes',
#      'emanuel.duraes@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Born Be Wild'])],
#   1),
#  ('NA',
#   [('João Manuel Dias Rei',
#     ['21/07/72',
#      'Rua do Areal, V.F.S.Martinho, Barcelos',
#      'joao.rei@sapo.pt',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'na'])],
#   1),
#  ('OLHARES SUBLIMES',
#   [('Francisco Terra',
#     ['30/10/80',
#      'São João da Madeira',
#      'franciscomsterra@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Olhares Sublimes'])],
#   1),
#  ('TEAM DUAS FACES',
#   [('João Moutinho',
#     ['01/12/80',
#      'Rua da Fonte 116 4445-114 Alfena',
#      'jnm@fe.up.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Team DUAS FACES'])],
#   1),
#  ('DURO VL',
#   [('João Marafona',
#     ['16/06/66',
#      'Av. 27 de Fevereiro, 93, 7º dto',
#      'jmarafona@sapo.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'DURO VL'])],
#   1),
#  ('CTAD TIAGOARAGAO.COM',
#   [('victor fernandes',
#     ['03/05/77',
#      'Rua de Goa, nº7, 4450 Matosinhos',
#      'victormcfernandes@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'CTAD tiagoaragao.com'])],
#   1),
#  ('XICO RUNNERS',
#   [('Pedro Manuel da Silva Mendes Fernandes',
#     ['05/01/79',
#      'Guimarães',
#      'pfernandesgmr@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'XICO RUNNERS'])],
#   1),
#  ('O MONGE DO RUNNING',
#   [('António Fernandes',
#     ['24/05/77',
#      'Rua S. Tiago Nº297, Caldelas',
#      'cisterbtt@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'O Monge do Running'])],
#   1),
#  ("CÃES D'AVENIDA",
#   [('joao lelis',
#     ['28/03/74',
#      'av brasil, 829 - 4',
#      'joao_lelis@hotmail.com',
#      'Ultra Trail',
#      'M40',
#      "cães d'avenida"])],
#   1),
#  ('LOUSADA RUNNERS',
#   [('Hugo Almeida',
#     ['19/08/75',
#      'rua do alecrim 109',
#      'hugo.btt@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'lousada runners'])],
#   1),
#  ('SUPERFRAQUINHOS',
#   [('António Manuel de Araújo Mendes',
#     ['26/06/77',
#      'Casa do Outeiro n 40 - lugar da bouça',
#      'antonioivv@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Superfraquinhos'])],
#   1),
#  ('IND.',
#   [('Guilherme Godinho',
#     ['05/01/70',
#      'Santo Tirso',
#      'godinhop@sapo.pt',
#      'Ultra Trail',
#      'M40',
#      'Ind.'])],
#   1),
#  ('MRR',
#   [('Pedro Ferreira',
#     ['09/03/82',
#      'Porto / Maia',
#      'pedro.helpdesk@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'MRR'])],
#   1),
#  ('TRAIL RUNNING ESPOSENDE',
#   [('Americo Machado',
#     ['12/11/78',
#      'Ald. Areia Nova, Lt-Sul, Fr- AA Cepães Esposende',
#      'americomachado211@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Trail Running Esposende'])],
#   1),
#  ('DESNÍVEL POSITIVO',
#   [('Sérgio Vidal',
#     ['09/01/77',
#      'Rua da Paz, 435, 2.º Drt, Frt, 4400-542 Gaia',
#      'nonoeserginho@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Desnível Positivo'])],
#   1),
#  ('PARJOVEM PAREDES',
#   [('Raul Luis Ribeiro Coelho',
#     ['23/05/81',
#      'Paredes',
#      'raul.luis.coelho@gmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'ParJovem Paredes'])],
#   1),
#  ('C. D. R. C. AMARENSE',
#   [('José Pedro Vieira Costa',
#     ['29/11/93',
#      'Rua Bairro Municipal nº 27 Amares',
#      'zp-saul@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'C. D. R. C. AMARENSE'])],
#   1),
#  ('GBES',
#   [('CARLA ANDRE',
#     ['09/05/77',
#      'r diogo barbosa machado Cascais',
#      'carlanunesandre@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Fem',
#      'GBES'])],
#   1),
#  ('INOV8SPORTLAST',
#   [('Jose Manuel',
#     ['14/05/83',
#      'Gondomar',
#      'oaciecnoc@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Inov8Sportlast'])],
#   1),
#  ('FALCÕES SELVAGENS',
#   [('Ana lucia Duarte',
#     ['03/07/70',
#      'rua da lapa n.2 r/C 2665-554 Venda do Pinheiro',
#      'lucyclinica@gmail.com',
#      'Ultra Trail',
#      'F40',
#      'Falcões Selvagens'])],
#   1),
#  ('DUROS DE ROER',
#   [('Paulo Rodrigues',
#     ['26/01/77',
#      'Rua Dr José Sousa Machado N47 2º D 4710-383 Braga',
#      'pr2734@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Duros de Roer'])],
#   1),
#  ('AMIGOS DOS TRILHOS DE ESMERIZ',
#   [('Francisco Ismael Moniz Carneiro',
#     ['03/02/77',
#      'Rua João Paulo II nº222, Esmeriz Vila Nova de Famalicão',
#      'fimc.francisco@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Amigos dos Trilhos de Esmeriz'])],
#   1),
#  ('CLUBE NAUTICO DE PONTE DE LIMA',
#   [('Luís António Rocha Magalhães',
#     ['09/07/71',
#      'Braga',
#      'geral.pontocom@gmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Clube Nautico de Ponte de Lima'])],
#   1),
#  ('TRAILEMPENADOS',
#   [('David Gomes',
#     ['04/04/83',
#      'Rua Amalia Rodrigues n3 2º Esquerdo',
#      'david.peixoto.gomes@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'TrailEmpenados'])],
#   1),
#  ('ND',
#   [('andre jorge araujo pinheiro',
#     ['20/06/77',
#      'rua rodrigo terroso nº 252 4760-792 V.N.FAMALICAO',
#      'andrearkan@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'nd'])],
#   1),
#  ('OS MARRAFONAS',
#   [('Jorge Moreira',
#     ['04/12/78',
#      'Vila Nova Famalicão',
#      'jorgemoreira78@hotmail.com',
#      'Corrida da Geira',
#      'SENIOR Masc',
#      'Os Marrafonas'])],
#   1),
#  ('SEISSAACRRORIZMATIAS&ARAUJO FRULACT',
#   [('Ricardo Andre Ramos Miranda',
#     ['11/07/89',
#      'Rua do Montinho n.º 346 Vila Cova',
#      'Ricardo_andre21@hotmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'SEISSAACRRORIZMATIAS&ARAUJO FRULACT'])],
#   1),
#  ('GD AIRÃO',
#   [('Carlos Castro',
#     ['27/11/68',
#      'Braga',
#      'castro.sov@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'GD Airão'])],
#   1),
#  ('NODDY BIKE TEAM',
#   [('Hugo Hernani Pimenta Sousa Faria',
#     ['29/12/74',
#      'Avenida Central N°28 Arcozelo 4750-132 Barcelos',
#      'bicigalos@portugalmail.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Noddy Bike Team'])],
#   1),
#  ('NME',
#   [('Daniel Filipe Pereira Lacerda',
#     ['03/10/75',
#      'Rua Dr. Manuel Neves Casal nº423',
#      'danielfplacerda@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'NME'])],
#   1),
#  ('ASOCIACION DEPORTIVA C.A.R REDONDELA',
#   [('Fernando Lago Castro',
#     ['09/12/72',
#      'Doctor Marañon 12entreplanta. Vigo-Pontevedra',
#      'martasoto85@gmail.com',
#      'Ultra Trail',
#      'M40',
#      'Asociacion deportiva C.A.R Redondela'])],
#   1),
#  ('NAZABÓBODA',
#   [('Sérgio Montes',
#     ['23/12/77',
#      'Rua Elias Garcia n.º 149 2.ºDT 2735-267 Cacém',
#      'runsergiorun@portugalmail.pt',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'NAZAbóboda'])],
#   1),
#  ('I-RUN',
#   [('Antonio Vasconcelos Carvalho',
#     ['16/04/54',
#      'Rua Joao Paulo II - 66 4420-168 Gondomar',
#      'gab.a.vasconcelos@hotmail.com',
#      'Ultra Trail',
#      'M50',
#      'I-RUN'])],
#   1),
#  ('PENAQEMPENA RUNNERS',
#   [('João Pedro',
#     ['21/02/86',
#      'Rua Emídio Gomes da Silva, rc dir',
#      'joaoplaranjeira@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'PenaQEmpena Runners'])],
#   1),
#  ('SUPERFRAQUINHOS  MINHO AVENTURA',
#   [('José J. Machado',
#     ['24/05/77',
#      'Rua Andrade Corvo 74 2.Esq',
#      'josemachado.ec@gmail.com',
#      'Ultra Trail',
#      'SENIOR Masc',
#      'Superfraquinhos  Minho Aventura'])],
#   1)]

# %%
def htmljogadorMake(equipa, tuplogamer):
    equipa=equipa.replace(" ", "")
    grant=True;
    pastadeequipa = 'PastaHtml'+'/'+equipa
    if not os.path.exists(pastadeequipa):
        os.mkdir(pastadeequipa)
    nomeHtml= pastadeequipa+'/'+ tuplogamer[0].replace(" ", "") +'.html'
    print(nomeHtml)
    if not os.path.exists(nomeHtml):
        f = open(nomeHtml, "w")

        f.write('''<html>
            <head><title>Informação de Jogador</title></head>
            <body>''')
        f.write('<Jogador> <h2>'+ tuplogamer[0] +'</h2><br>')
        f.write('<dataNasc>'+ 'Data de Nascimento: '+ tuplogamer[1][0]+';'+'</dataNasc><br>')
        f.write('<morada>'+ 'Morada: '+ tuplogamer[1][1]+';'+'</morada><br>')
        f.write('<email>'+ 'Email: '+ tuplogamer[1][2]+';'+'</email><br>')
        f.write('<provas>'+ 'Provas: '+ tuplogamer[1][3]+';'+'</provas><br>')
        f.write('<escalao>'+ 'Escalão: '+ tuplogamer[1][4]+';'+'</escalao><br>')
        f.write('<equipa>'+ 'Equipa: '+ tuplogamer[1][5]+';'+'</equipa><br>')
        f.write('</Jogador>')
        f.write('</body> </html>')
        f.close()
    else: 
        grant=False;
        f = open(nomeHtml, "r")
        cont=f.read()
        cont=re.sub(r'<provas>Provas:','<provas>Provas:'+tuplogamer[1][3]+'; ',cont)
        f.close()
        f = open(nomeHtml, "w")
        f.write(cont)
        f.close()
        
    
    return equipa+'/'+ tuplogamer[0].replace(" ", "") +'.html',grant

# %%
htmljogadorMake(lfinal[1][0], lfinal[1][1][1])
# Out:
# PastaHtml/TURBULENTOS/PauloPimentelTorres.html
# ('TURBULENTOS/PauloPimentelTorres.html', False)

# %%
def html1Make(lfinal):
    nomeHtml= 'PastaHtml'+'/'+'testePL.html'
    print(nomeHtml)
    if not os.path.exists('PastaHtml'):
        os.mkdir('PastaHtml')
    f = open(nomeHtml, "w")
    f.write('''<html>
    <head><title>Lista de Todas as equipas</title></head>
    <body>''')
    for i in lfinal:
        f.write('<equipa> <h2>'+i[0] +'</h2><br>')
        for j in range(len(i[1])):
            link, grant = htmljogadorMake(i[0], i[1][j])
            if grant:
                f.write('<jogador>'+i[1][j][0]+'</jogador><br>')
                f.write('<a href='+link+'>link</a><br>')
        
        f.write('</equipa>')
    f.write('</body> </html>')
    f.close()
    return

# %%
html1Make(lfinal)
# Out:
# PastaHtml/testePL.html
# PastaHtml/INDIVIDUAL/MARIOPIRES.html
# PastaHtml/INDIVIDUAL/FranciscoNetoSilva.html
# PastaHtml/INDIVIDUAL/ArturBernardo.html
# PastaHtml/INDIVIDUAL/VeraCristinaMoreiraDelgado.html
# PastaHtml/INDIVIDUAL/JorgeYong.html
# PastaHtml/INDIVIDUAL/PauloSerra.html
# PastaHtml/INDIVIDUAL/TiagoJoséCadimaBorges.html
# PastaHtml/INDIVIDUAL/jorgemanuelmartinssilva.html
# PastaHtml/INDIVIDUAL/PauloDomingues.html
# PastaHtml/INDIVIDUAL/DulceMoreda.html
# PastaHtml/INDIVIDUAL/AntónioFernandes.html
# PastaHtml/INDIVIDUAL/VeraCristinaMoreiraDelgado.html
# PastaHtml/INDIVIDUAL/AngeloSenra.html
# PastaHtml/INDIVIDUAL/PauloJorge.html
# PastaHtml/INDIVIDUAL/AntónioFernandes.html
# PastaHtml/INDIVIDUAL/VitorMarques.html
# PastaHtml/INDIVIDUAL/SérgioMartins.html
# PastaHtml/INDIVIDUAL/NunoLima.html
# PastaHtml/INDIVIDUAL/PaulaCristinaOliveira.html
# PastaHtml/INDIVIDUAL/Nunocoelhosilva.html
# PastaHtml/INDIVIDUAL/ArturFerreira.html
# PastaHtml/INDIVIDUAL/VascoOrtigãodeOliveira.html
# PastaHtml/INDIVIDUAL/RicardoJorgeDiasOliveira.html
# PastaHtml/INDIVIDUAL/NunoCarvalhal.html
# PastaHtml/INDIVIDUAL/AndreSousa.html
# PastaHtml/INDIVIDUAL/SusanaDias.html
# PastaHtml/INDIVIDUAL/MarcoTiagoMarquesRodrigues.html
# PastaHtml/INDIVIDUAL/MarcoTiagoMarquesRodrigues.html
# PastaHtml/INDIVIDUAL/elisabetecosta.html
# PastaHtml/INDIVIDUAL/AntonioLafuenteCoelhodeAzevedo.html
# PastaHtml/INDIVIDUAL/RuiAndréSantosOliveira.html
# PastaHtml/INDIVIDUAL/CarlosFreitas.html
# PastaHtml/INDIVIDUAL/MiguelBorges.html
# PastaHtml/INDIVIDUAL/sergioferreirarodrigues.html
# PastaHtml/INDIVIDUAL/JorgeCosta.html
# PastaHtml/INDIVIDUAL/carlasofialimaleitenunesgarcez.html
# PastaHtml/INDIVIDUAL/AlbertoCésar.html
# PastaHtml/INDIVIDUAL/JoséMendes.html
# PastaHtml/INDIVIDUAL/JoaquimAlves.html
# PastaHtml/INDIVIDUAL/VitorPedroSilva.html
# PastaHtml/INDIVIDUAL/SusanaNeta.html
# PastaHtml/INDIVIDUAL/AlbertoCésar.html
# PastaHtml/INDIVIDUAL/VitorMarques.html
# PastaHtml/INDIVIDUAL/JosePereira.html
# PastaHtml/INDIVIDUAL/RodrigoMiguel.html
# PastaHtml/INDIVIDUAL/JoãoRicardoTavaresNeves.html
# PastaHtml/INDIVIDUAL/CarlosFigueiredo.html
# PastaHtml/INDIVIDUAL/AlbertoBarros.html
# PastaHtml/INDIVIDUAL/AmândioAntunes.html
# PastaHtml/INDIVIDUAL/PatríciaAmorim.html
# PastaHtml/INDIVIDUAL/AntónioFernandoFins.html
# PastaHtml/INDIVIDUAL/RuiManuelAlvesMonteiroAraujo.html
# PastaHtml/INDIVIDUAL/PedroCastro.html
# PastaHtml/INDIVIDUAL/RuiPedroRibeiroFerreira.html
# PastaHtml/INDIVIDUAL/LigiaSusanaMiguelDias.html
# PastaHtml/INDIVIDUAL/JoanaAzevedo.html
# PastaHtml/INDIVIDUAL/RuiSantos.html
# PastaHtml/INDIVIDUAL/carlosmanuelmendespereira.html
# PastaHtml/INDIVIDUAL/LuisMelo.html
# PastaHtml/INDIVIDUAL/OlgaMelo.html
# PastaHtml/INDIVIDUAL/RicardoErnestodosSantosGeraldesDomingues.html
# PastaHtml/INDIVIDUAL/AlexandreSolposto.html
# PastaHtml/INDIVIDUAL/RuiPinto.html
# PastaHtml/TURBULENTOS/JoãoCosta.html
# PastaHtml/TURBULENTOS/PauloPimentelTorres.html
# PastaHtml/TURBULENTOS/JoãoPimentelTorres.html
# PastaHtml/TURBULENTOS/VascoManueldeSequeirosBarretoMartinsdeAraújo.html
# PastaHtml/TURBULENTOS/CelesteCruz.html
# PastaHtml/TURBULENTOS/JorgeLourenço.html
# PastaHtml/TURBULENTOS/LuísMelo.html
# PastaHtml/TURBULENTOS/MarioJorgeAorimm.html
# PastaHtml/TURBULENTOS/LuisBPereira.html
# PastaHtml/TURBULENTOS/PauloAntunes.html
# PastaHtml/TURBULENTOS/CarlosAlbertoGomesTeixeira.html
# PastaHtml/TURBULENTOS/ManelAlbertoLeitedeSousa.html
# PastaHtml/TURBULENTOS/GiuseppeBaldassarre.html
# PastaHtml/TURBULENTOS/HelenaOliveira.html
# PastaHtml/TURBULENTOS/PauloAntunes.html
# PastaHtml/TURBULENTOS/MarinhaPaulaFernandes.html
# PastaHtml/TURBULENTOS/CátiaRaquelMacedoOliveira.html
# PastaHtml/TURBULENTOS/ManuelCoutinhoMachado.html
# PastaHtml/TURBULENTOS/TiagoDominguesFrada.html
# PastaHtml/TURBULENTOS/AntónioJoséCosta.html
# PastaHtml/TURBULENTOS/TiagoDominguesFrada.html
# PastaHtml/TURBULENTOS/MarioJorgeAorimm.html
# PastaHtml/TURBULENTOS/JoséFerreiraLoureiro.html
# PastaHtml/TURBULENTOS/CarlosManuelGonçalvesVieiraFernandes.html
# PastaHtml/TURBULENTOS/JoseAlbertoMartins.html
# PastaHtml/TURBULENTOS/SandraMariaFinsterraTravessas.html
# PastaHtml/TURBULENTOS/FranciscoAntóniodosSantosCostas.html
# PastaHtml/TURBULENTOS/CarlosBrito.html
# PastaHtml/TURBULENTOS/elisabetecosta.html
# PastaHtml/TURBULENTOS/AntónioFerreira.html
# PastaHtml/TURBULENTOS/AntónioJoséVelosodosSantos.html
# PastaHtml/TURBULENTOS/ANAMOREIRA.html
# PastaHtml/TURBULENTOS/JoãoNunoFerreiraCruzPinto.html
# PastaHtml/TURBULENTOS/MÁRIORAMOS.html
# PastaHtml/TURBULENTOS/ConceiçãoMarques.html
# PastaHtml/TURBULENTOS/SérgioSilva.html
# PastaHtml/TURBULENTOS/PaulaMatos.html
# PastaHtml/TURBULENTOS/SheilaPereiraKhan.html
# PastaHtml/TURBULENTOS/RuiGomes.html
# PastaHtml/TURBULENTOS/JoséMariaRibeiroVieiradeFigueiredo.html
# PastaHtml/NAST/FERNANDOJORGEMENDESCARNEIRO.html
# PastaHtml/NAST/GonçaloMota.html
# PastaHtml/NAST/JulioAntonioCunhaPeixotoBraga.html
# PastaHtml/NAST/HelderFernandoVieiraAzevedo.html
# PastaHtml/NAST/SérgioPaulodosSantosSá.html
# PastaHtml/NAST/AnalbertoBarrosdosSantos.html
# PastaHtml/NAST/RicardoJorgeDiasOliveira.html
# PastaHtml/NAST/CarlosManuelOliveiraBras.html
# PastaHtml/NAST/AnaCarolinaLopesFerreira.html
# PastaHtml/NAST/SóniaDoloresFerreiraAlves.html
# PastaHtml/NAST/DeborahAlexandraLopesMoreira.html
# PastaHtml/NAST/JulioAntonioCunhaPeixotoBraga.html
# PastaHtml/EDVVIANATRAIL/GabrielFagundesMeira.html
# PastaHtml/EDVVIANATRAIL/JoséDomingosFernandesdosSantos.html
# PastaHtml/EDVVIANATRAIL/MariadoRosárioSantos.html
# PastaHtml/EDVVIANATRAIL/NatalinaSantos.html
# PastaHtml/EDVVIANATRAIL/AndréSaleiro.html
# PastaHtml/EDVVIANATRAIL/RuiCouto.html
# PastaHtml/EDVVIANATRAIL/RosaLobato.html
# PastaHtml/EDVVIANATRAIL/AnabelaLobato.html
# PastaHtml/EDVVIANATRAIL/AlexandroRibeiro.html
# PastaHtml/EDVVIANATRAIL/ArlindoAlvesRodrigues.html
# PastaHtml/ARRASTASSOLAS/PedroCarvalho.html
# PastaHtml/ARRASTASSOLAS/PedroMagalhaes.html
# PastaHtml/ARRASTASSOLAS/PedroLopes.html
# PastaHtml/ARRASTASSOLAS/MarioSantos.html
# PastaHtml/ARRASTASSOLAS/VitorSilva.html
# PastaHtml/ARRASTASSOLAS/HelenaCunha.html
# PastaHtml/ARRASTASSOLAS/CarlaMoreira.html
# PastaHtml/ARRASTASSOLAS/ManuelSILVA.html
# PastaHtml/MULTIPOWER|GAIATRAIL/JoãoPedroPedrosaNunes.html
# PastaHtml/MULTIPOWER|GAIATRAIL/JoãoPedroPedrosaNunes.html
# PastaHtml/MULTIPOWER|GAIATRAIL/JoãoPedroPedrosaNunes.html
# PastaHtml/MULTIPOWER|GAIATRAIL/JoãoPedroPedrosaNunes.html
# PastaHtml/MULTIPOWER|GAIATRAIL/JoséHenriquePintodeOliveira.html
# PastaHtml/MULTIPOWER|GAIATRAIL/FranciscoJoséCarneiroOliveira.html
# PastaHtml/MULTIPOWER|GAIATRAIL/AndréPeixotoCostaAssunção.html
# PastaHtml/PRINTTEAM/CarlosFigueiredo.html
# PastaHtml/PRINTTEAM/AbilioAraujo.html
# PastaHtml/PRINTTEAM/VeraCosta.html
# PastaHtml/PRINTTEAM/EugeniaSouto.html
# PastaHtml/PRINTTEAM/SusanaFigueiredo.html
# PastaHtml/PRINTTEAM/ClaudiaAngeira.html
# PastaHtml/PRINTTEAM/PedroAvelinoSilva.html
# PastaHtml/PORTORUNNERS/LuisSantosPoeira.html
# PastaHtml/PORTORUNNERS/JoséFernanadesFerreira.html
# PastaHtml/PORTORUNNERS/JorgeMiguelMarques.html
# PastaHtml/PORTORUNNERS/luisfranciscomatosmarvao.html
# PastaHtml/PORTORUNNERS/NunoCáceres.html
# PastaHtml/PORTORUNNERS/PedroViana.html
# PastaHtml/CLUBEDEVETERANOSDOPORTO/paulodecastrorocha.html
# PastaHtml/CLUBEDEVETERANOSDOPORTO/NunoManuelCaldeiradeSá.html
# PastaHtml/CLUBEDEVETERANOSDOPORTO/ManuelPereira.html
# PastaHtml/CLUBEDEVETERANOSDOPORTO/antóniocosta.html
# PastaHtml/CLUBEDEVETERANOSDOPORTO/manuelpereira.html
# PastaHtml/CLUBEDEVETERANOSDOPORTO/NunoManuelCaldeiradeSá.html
# PastaHtml/COMPANHIADOBAZÓFIAS/ArturJoséPintoMendesdaCosta.html
# PastaHtml/COMPANHIADOBAZÓFIAS/VeraManuelaCardosodaSilva.html
# PastaHtml/COMPANHIADOBAZÓFIAS/FilipeManuelPedroBaptistaJesusNascimento.html
# PastaHtml/COMPANHIADOBAZÓFIAS/JoãoPedroMartins.html
# PastaHtml/COMPANHIADOBAZÓFIAS/FernandoAntónioRothes.html
# PastaHtml/COMPANHIADOBAZÓFIAS/PedroMiguelAzevedodeSousaMelo.html
# PastaHtml/CLUBENÁUTICODEPONTEDELIMA/RafaelBritoAbreuPereira.html
# PastaHtml/CLUBENÁUTICODEPONTEDELIMA/AndreiaCunha.html
# PastaHtml/CLUBENÁUTICODEPONTEDELIMA/jorgeamorim.html
# PastaHtml/CLUBENÁUTICODEPONTEDELIMA/SaradaCostaSáCorreia.html
# PastaHtml/CLUBENÁUTICODEPONTEDELIMA/SaradaCostaSáCorreia.html
# PastaHtml/CLUBENÁUTICODEPONTEDELIMA/RenatoMartins.html
# PastaHtml/CLUBEATLETISMODELAMAS/CarlosAlbertodaSilvaCardoso.html
# PastaHtml/CLUBEATLETISMODELAMAS/RuiGilbertoSantosCorreia.html
# PastaHtml/CLUBEATLETISMODELAMAS/JoséMoreira.html
# PastaHtml/CLUBEATLETISMODELAMAS/HélderSilva.html
# PastaHtml/CLUBEATLETISMODELAMAS/JOSECOELHO.html
# PastaHtml/TUGASNAESTRADA/MariadeFatimaBatistaGeraldes.html
# PastaHtml/TUGASNAESTRADA/pauloVilaça.html
# PastaHtml/TUGASNAESTRADA/RicardoSilva.html
# PastaHtml/TUGASNAESTRADA/RicardoSilva.html
# PastaHtml/TUGASNAESTRADA/RicardoSilva.html
# PastaHtml/NAN/ConstânciaJoanaDiasMartins.html
# PastaHtml/NAN/JoaquimMiguelAbreuFariadeCarvalho.html
# PastaHtml/NAN/JoãoMartinsFaria.html
# PastaHtml/NAN/AnaPaulaDiasQueirosGomes.html
# PastaHtml/NAN/AnaIsabelDiasGranjo.html
# PastaHtml/INDIVUDUAL/JOSECARLINDODUARTECARVALHO.html
# PastaHtml/INDIVUDUAL/NunoLima.html
# PastaHtml/INDIVUDUAL/SilviaQuintiães.html
# PastaHtml/INDIVUDUAL/SIMÃOGRADISSIMO.html
# PastaHtml/CLUBESPIRIDONDEGAIA/MarleneFonseca.html
# PastaHtml/CLUBESPIRIDONDEGAIA/CândidoSilva.html
# PastaHtml/CLUBESPIRIDONDEGAIA/CéliaDias.html
# PastaHtml/CLUBESPIRIDONDEGAIA/DanielCaeiro.html
# PastaHtml/OSBARRIGUITAS/josemouradesousa.html
# PastaHtml/OSBARRIGUITAS/ManuelMoura.html
# PastaHtml/OSBARRIGUITAS/RicardoSousa.html
# PastaHtml/EDV-VIANATRAIL/SoniaParente.html
# PastaHtml/EDV-VIANATRAIL/CéliaAzevedo.html
# PastaHtml/EDV-VIANATRAIL/JoséManuelSantosFaria.html
# PastaHtml/BRACARARUNNERS/MauroFernandes.html
# PastaHtml/BRACARARUNNERS/RuiFilipe.html
# PastaHtml/BRACARARUNNERS/RuiFilipe.html
# PastaHtml/SOPRORUNLIFE/RenatoLopes.html
# PastaHtml/SOPRORUNLIFE/MoisésFerreira.html
# PastaHtml/SOPRORUNLIFE/paulofélix.html
# PastaHtml/ECOBIKEPORTO/LeandroCosta.html
# PastaHtml/ECOBIKEPORTO/LeandroCosta.html
# PastaHtml/ECOBIKEPORTO/LeandroCosta.html
# PastaHtml/OSCAGATACOSRUNNINGTEAN/BrunoManuelHenriquesMaceda.html
# PastaHtml/OSCAGATACOSRUNNINGTEAN/HelderMatos.html
# PastaHtml/SCLUBE/brunofilipedesacampelo.html
# PastaHtml/SCLUBE/brunofilipedesacampelo.html
# PastaHtml/.COM/SérgioDuarte.html
# PastaHtml/.COM/CelesteCruz.html
# PastaHtml/UNIÃOFCIDETOMAR/PedroAlbino.html
# PastaHtml/UNIÃOFCIDETOMAR/PedroAlbino.html
# PastaHtml/OSTURBULENTOS/FernandoManuelTavaresdaCostaAntunes.html
# PastaHtml/OSTURBULENTOS/FernandoManuelTavaresdaCostaAntunes.html
# PastaHtml/TEMPLARTRAIL/JaimeFilipeBarros.html
# PastaHtml/TEMPLARTRAIL/MariaJoséValente.html
# PastaHtml/CAVE/manuelbraga.html
# PastaHtml/CAVE/manuelbraga.html
# PastaHtml/URBANTEAM/RicardoCampos.html
# PastaHtml/URBANTEAM/RuiCampos.html
# PastaHtml/JC&NIKI/JoséCunha.html
# PastaHtml/JC&NIKI/MonicaEsteves.html
# PastaHtml/PRTADQUINTA/HugoSa.html
# PastaHtml/PRTADQUINTA/RicardoReis.html
# PastaHtml/CLUBENÁUTICOPONTEDELIMA/LuisGonçalves.html
# PastaHtml/CLUBENÁUTICOPONTEDELIMA/NunoMiguelMoraisFreitas.html
# PastaHtml/OSTURBOLENTOS/NunoAmorimSilva.html
# PastaHtml/OSTURBOLENTOS/LuisRegodaSilva.html
# PastaHtml/MINHOAVENTURA/PedroNóvoa.html
# PastaHtml/MINHOAVENTURA/PedroNóvoa.html
# PastaHtml/CABRITOSDACORTIÇA-TRAIL/RaulCerdeira.html
# PastaHtml/CABRITOSDACORTIÇA-TRAIL/RicardoCouto.html
# PastaHtml/PEDROS&ASSOCIADOS/RicardodaSilvaPedro.html
# PastaHtml/PEDROS&ASSOCIADOS/AnaCatarinaReisPeixoto.html
# PastaHtml/CLUBEPORTUGALTELECOMZONANORTE/PedroJoséGonçalvesBraga.html
# PastaHtml/CLUBEPORTUGALTELECOMZONANORTE/RuiVitorFigueirasMeireles.html
# PastaHtml/BANDODOSTRILHOSETRALHOS,ASSOCIAÇÃOBETETISTA/BrunoAlexandreOliveiraGraça.html
# PastaHtml/BANDODOSTRILHOSETRALHOS,ASSOCIAÇÃOBETETISTA/RuiManuelAlmeidaGaspar.html
# PastaHtml/CÃESDAAVENIDA/RicardoSalgueiro.html
# PastaHtml/OSCAGATACOSRUNNINGTEAM/JPauloMarques.html
# PastaHtml/BLUEO/SérgioMoreira.html
# PastaHtml/BORNBEWILD/EmanuelDurães.html
# PastaHtml/NA/JoãoManuelDiasRei.html
# PastaHtml/OLHARESSUBLIMES/FranciscoTerra.html
# PastaHtml/TEAMDUASFACES/JoãoMoutinho.html
# PastaHtml/DUROVL/JoãoMarafona.html
# PastaHtml/CTADTIAGOARAGAO.COM/victorfernandes.html
# PastaHtml/XICORUNNERS/PedroManueldaSilvaMendesFernandes.html
# PastaHtml/OMONGEDORUNNING/AntónioFernandes.html
# PastaHtml/CÃESD'AVENIDA/joaolelis.html
# PastaHtml/LOUSADARUNNERS/HugoAlmeida.html
# PastaHtml/SUPERFRAQUINHOS/AntónioManueldeAraújoMendes.html
# PastaHtml/IND./GuilhermeGodinho.html
# PastaHtml/MRR/PedroFerreira.html
# PastaHtml/TRAILRUNNINGESPOSENDE/AmericoMachado.html
# PastaHtml/DESNÍVELPOSITIVO/SérgioVidal.html
# PastaHtml/PARJOVEMPAREDES/RaulLuisRibeiroCoelho.html
# PastaHtml/C.D.R.C.AMARENSE/JoséPedroVieiraCosta.html
# PastaHtml/GBES/CARLAANDRE.html
# PastaHtml/INOV8SPORTLAST/JoseManuel.html
# PastaHtml/FALCÕESSELVAGENS/AnaluciaDuarte.html
# PastaHtml/DUROSDEROER/PauloRodrigues.html
# PastaHtml/AMIGOSDOSTRILHOSDEESMERIZ/FranciscoIsmaelMonizCarneiro.html
# PastaHtml/CLUBENAUTICODEPONTEDELIMA/LuísAntónioRochaMagalhães.html
# PastaHtml/TRAILEMPENADOS/DavidGomes.html
# PastaHtml/ND/andrejorgearaujopinheiro.html
# PastaHtml/OSMARRAFONAS/JorgeMoreira.html
# PastaHtml/SEISSAACRRORIZMATIAS&ARAUJOFRULACT/RicardoAndreRamosMiranda.html
# PastaHtml/GDAIRÃO/CarlosCastro.html
# PastaHtml/NODDYBIKETEAM/HugoHernaniPimentaSousaFaria.html
# PastaHtml/NME/DanielFilipePereiraLacerda.html
# PastaHtml/ASOCIACIONDEPORTIVAC.A.RREDONDELA/FernandoLagoCastro.html
# PastaHtml/NAZABÓBODA/SérgioMontes.html
# PastaHtml/I-RUN/AntonioVasconcelosCarvalho.html
# PastaHtml/PENAQEMPENARUNNERS/JoãoPedro.html
# PastaHtml/SUPERFRAQUINHOSMINHOAVENTURA/JoséJ.Machado.html
